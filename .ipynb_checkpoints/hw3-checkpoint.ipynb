# %% [markdown]
# # Homework 5: Lexicons and Distributional Semantics
#
# This is due on **Friday, 11/10 (11pm)**
#
# ## How to do this problem set
#
# Most of these questions require writing Python code and computing results, and the rest of them have textual answers.  Write all the textual answers in this document, show the output of your experiment in this document, and implement the functions in the `python` files.
#
# Submit a PDF of thie .ipynb to Gradescope, and the .ipynb and all python files to Moodle.
#
# The assignment has two parts:
#  * In the first part, you will experiment with Turney's method to find word polarities in a twitter dataset, given some positive and negative seed words.
#  * In the second part, you will experiment with distributional and vector semantics.

# %% [markdown]
# **Jucong He**
#
# **List collaborators, and how you collaborated, here:** (see our [grading and policies page](http://people.cs.umass.edu/~brenocon/inlp2017/grading.html) for details on our collaboration policy).
#
# * _name 1_

# %% [markdown]
# ## Part 1: Lexicon semantics

# %% [markdown]
# Recall that PMI of a pair of words, is defined as:
#
# $$PMI(x, y) = log\frac{ P(x, y) }{ P(x)P(y)}$$
#
# The Turney mehod defines a word's polarity as:
#
# $$Polarity(word) = PMI(word, positive\_word)−PMI(word, negative\_word)$$
#
# where the joint probability $P(w, v)$ or, more specifically, $P(w\ NEAR\ v)$ is the probability of both being "near" each other.  We'll work with tweets, so it means: if you choose a tweet at random, what's the chance it contains both `w` and `v`?
#
# (If you look at the Turney method as explained in the SLP3 chapter, the "hits" function is a count of web pages that contain at least one instance of the two words occurring near each other.)
#
# The positive_word and negative_word terms are initially constructed by hand. For example: we might start with single positive word ('excellent') and a single negative word ('bad'). We can also have list of positive words ('excellent', 'perfect', 'love', ....) and list of negative words ('bad', 'hate', 'filthy',....)
#
# If we're using a seed list of multiple terms, just combine them into a single symbol, e.g. all the positive seed words get rewritten to POS_WORD (and similarly for NEG_WORD).  This $P(w, POS\_WORD)$ effectively means the co-ocurrence of $w$ with any of the terms in the list.
#
# For this assignment, we will use twitter dataset which has 349378 tweets. These tweets are in the file named `tweets.txt`. These are the tweets of one day and filtered such that each tweet contains at least one of the seed words we've selected.

# %% [markdown]
# ## Question 1 (15 points)
#
# The file `tweets.txt` contains around 349,378 tweets with one tweet per line.  It is a random sample of public tweets, which we tokenized with [twokenize.py's tokenizeRawTweetText()](https://github.com/myleott/ark-twokenize-py/blob/master/twokenize.py)). The text you see has a space between each token so you can just use `.split()` if you want.  We also filtered tweets to ones that included at least one term from one of these seed lists:
# * Positive seed list: ["good", "nice", "love", "excellent", "fortunate", "correct", "superior"]
# * Negative seed list: ["bad", "nasty", "poor", "hate", "unfortunate", "wrong", "inferior"]
#
# Each tweet contains at least one positive or negative seed word. Take a look at the file (e.g. `less' and `grep'). Implement the Turney's method to calculate polarity scores of all words.
#
# Some things to keep in mind:
# * Ignore the seed words (i.e. don't calculate the polarity of the seed words).
# * You may want to ignore the polarity of words beignning with `@` or `#`.
#
# We recommend that you write code in a python file, but it's up to you.
#
# QUESTION: You'll have to do something to handle zeros in the PMI equation. Please explain your and justify your decision about this.

# %% [markdown]
# The P(x,y) might be zero because there might be some case that none of the tweets contain two words at the same time. My approch to handle this problem is assign the PMI to 0, because 0 doesn't effect the average while we are doing calculation in the log space.

# %% [markdown]
# ## Question 2 (5 points)
#
# Print the top 50 most-positive words (i.e. inferred positive words) and the 50 most-negative words.
#
# Many of the words won't make sense.  Comment on at least two that do make sense, and at least two that don't.  Why do you think these are happening with this dataset and method?

# %%
from polarity import *
# %load_ext autoreload
# %autoreload 2
word_count_dic, word_pair_count_dic = load_pickle()

# %%
print 'calculating polarity'
polarity_dic = calculate_polarity(word_count_dic, word_pair_count_dic)
print '\n=======positive=======\n'
sorted_polarity = sorted(polarity_dic.items(), key=lambda (w, c): -c)
for p in sorted_polarity[:50]:
    print p[0]
print '\n=======negative=======\n'
for p in reversed(sorted_polarity[-50:]):
    print p[0]
# Out:
# calculating polarity
#
# =======positive=======
#
# panel
# https://t.co/bltncugulr
# birthday
# hubby
# conn
# normal\
# ensemble
# anti-trump
# 👍
# fearless
# africans
# ma'am.
# 😊
# hood
# 💕
# colleagues
# dots
# distinction
# :d
# bounces
# decay
# drones
# pbo
# forces
# perth
# dana
# dinner
# makeup
# sane
# addition
# hello
# sellers
# tenders
# her\
# opportunities
# speaks
# goodbye
# touc…
# lukacs
# https://t.co/fdbx5rrpxf
# goodnight
# s/o
# definitions
# field
# indianan
# beautiful
# visit
# thanks
# london
# connecting
#
# =======negative=======
#
# bcoz
# families
# violent
# hateful
# trustworthy
# swallow
# paraded
# martyrdom
# civilization
# 2/
# corporations
# starve
# mantra
# prompt
# stomach
# whites
# exploited
# viral
# cleared
# 😷
# illustration
# introducing
# repulsive
# obamacare
# despicable
# officiating
# victims
# deaths
# gurmeher
# `
# https://t.co/bcd5vqb67i
# *)
# dgm
# (つω`*)
# ∀
# souls\
# v(´
# https://t.co/6twyf2xs44
# lorde…
# —audre
# moods
# medicaid
# 3.5
# aug
# plain
# raid
# behavior
# deviant
# justify
# slaves

# %% [markdown]
# Fearless and beautiful make as positive words while makeup and africans doesn't. This happen because the occurence of these word occurred is very low approximate to 0, as well as the occurence of these word and a posivite word occurred at the same time also very low. Then the positive PMI can be very high, like approximate 1. One the other hand, the negative is very low, like 0, because only few or none of the given word occured with a combination of a negative word. Thus, the polarity of these word is very high positive.

# %% [markdown]
# ## Question 3 (5 points)
#
# Now filter out all the words which have total count < 500, and then print top 50 polarity words and bottom 50 polarity words.
#
# Choose some of the words from both the sets of 50 words you got above which accoording to you make sense. Again please note, you will find many words which don't make sense. Do you think these results are better than the results you got in Question-1? Explain why.

# %%
polarity_dic = calculate_polarity(word_count_dic, word_pair_count_dic,filter=500)
sorted_polarity = sorted(polarity_dic.items(), key=lambda (w, c): -c)
for p in sorted_polarity[:50]:
    print p[0]
print '\n=======negative=======\n'
for p in reversed(sorted_polarity[-50:]):
    print p[0]
# Out:
# decay
# ol
# taylor
# pregnancy
# hood
# birthday
# ❤️
# ❤
# 😊
# hilarious
# morning
# d
# fall
# thank
# falling
# happy
# march
# beautiful
# thanks
# nadine
# amazing
# follow
# 😍
# proud
# loved
# soon
# :)
# forever
# feels
# sounds
# young
# !!
# together
# deserve
# you\
# support
# movie
# vibes
# !!!
# hope
# luck
# become
# music
# panalomoto
# |
# miss
# night
# god
# best
# true
#
# =======negative=======
#
# cigarettes
# condemning
# marijuana
# crimes
# i’ll
# stands
# beer
# forms
# store
# explain
# crime
# evil
# united
# ugly
# pick
# child
# against
# after
# w
# dems
# stand
# saf…
# ppl
# went
# parents
# american
# country
# men
# ask
# whole
# trump
# says
# idk
# left
# something
# myself
# every
# woman
# its
# women
# negative
# use
# especially
# believe
# must
# nothing
# send
# right
# going
# worse

# %% [markdown]
# The result is better than Question 1, because it avoid cases that high PMI value create by two low P(x,y) and P(x)P(y).

# %% [markdown]
# ## Question 4 (5 points)
#
# Even after filtering out words with count < 500, many top-most and bottom-most polarity don't make sense. Identify what kind of words these are and what can be done to filter them out. You can read some tweets in the file to see what's happening.

# %% [markdown]
# The top most word doesn't make sense, because inside the dataset there are a lot of same tweet contain decay and happy at the same time, this is kind of overfitting the training process. The bottom most word is worse, this happen because many tweet containt worse and a positive word at the same time. If the number of pos tweet contain worse or number of neg tweet contain worse is close to each other, then polarity of worse is approching 0.

# %% [markdown]
# # Part-2: Distributional Semantics

# %% [markdown]
# ## Cosine Similarity

# %% [markdown]
# Recall that, where $i$ indexes over the context types, cosine similarity is defined as follows. $x$ and $y$ are both vectors of context counts (each for a different word), where $x_i$ is the count of context $i$.
#
# $$cossim(x,y) = \frac{ \sum_i x_i y_i }{ \sqrt{\sum_i x_i^2} \sqrt{\sum_i y_i^2} }$$
#
# The nice thing about cosine similarity is that it is normalized: no matter what the input vectors are, the output is between 0 and 1. One way to think of this is that cosine similarity is just, um, the cosine function, which has this property (for non-negative $x$ and $y$). Another way to think of it is, to work through the situations of maximum and minimum similarity between two context vectors, starting from the definition above.
#
# Note: a good way to understand the cosine similarity function is that the numerator cares about whether the $x$ and $y$ vectors are correlated. If $x$ and $y$ tend to have high values for the same contexts, the numerator tends to be big. The denominator can be thought of as a normalization factor: if all the values of $x$ are really large, for example, dividing by the square root of their sum-of-squares prevents the whole thing from getting arbitrarily large. In fact, dividing by both these things (aka their norms) means the whole thing can’t go higher than 1.
#
# In this problem we'll work with vectors of raw context counts.  (As you know, this is not necessarily the best representation.)

# %% [markdown]
# ## Question 5 (5 points)
#
# See the file `nytcounts.university_cat_dog`, which contains context count vectors for three words: “dog”, “cat”, and “university”. These are immediate left and right contexts from a New York Times corpus. You can open the file in a text editor since it’s quite small.
#
# Write a function which takes context count dictionaries of two words and calculates cosine similarity between these two words. The function should return a number beween 0 and 1.  Briefly comment on whether the relative simlarities make sense.

# %%
import distsim; reload(distsim)

word_to_ccdict = distsim.load_contexts("nytcounts.university_cat_dog")
university = word_to_ccdict['university']
dog = word_to_ccdict['dog']
cat = word_to_ccdict['cat']
print distsim.cosine(university, dog)
print distsim.cosine(cat, dog)
print distsim.cosine(university, cat)

# write code here to show output (i.e. cosine similarity between these words.)
# We encourage you to write other functions in distsim.py itself.
# Out:
# file nytcounts.university_cat_dog has contexts for 3 words
# 0.661399002763
# 0.969045816976
# 0.663648140051

# %% [markdown]
# **Write your response here:**

# %% [markdown]
# ## Question 6 (20 points)
#
# Explore similarities in `nytcounts.4k`, which contains context counts for about 4000 words in a sample of New York Times articles. The news data was lowercased and URLs were removed. The context counts are for the 2000 most common words in twitter, as well as the most common 2000 words in the New York Times. (But all context counts are from New York Times.) The context counts only contain contexts that appeared for more than one word.  The file has three tab-separate fields: the word, its count, and a JSON-encoded dictionary of its context counts.  You'll see it's just counts of the immediate left/right neighbors.
#
# Choose **six** words. For each, show the output of 20 nearest words (use cosine similarity as distance metric). Comment on whether the output makes sense. Comment on whether this approach to distributional similarity makes more or less sense for certain terms.
# Four of your words should be:
#
#  * a name (for example: person, organization, or location)
#  * a common noun
#  * an adjective
#  * a verb
#
# You may also want to try exploring further words that are returned from a most-similar list from one of these. You can think of this as traversing the similarity graph among words.
#
# *Implementation note:*
# On my laptop it takes several hundred MB of memory to load it into memory from the `load_contexts()` function. If you don’t have enough memory available, your computer will get very slow because the OS will start swapping. If you have to use a machine without that much memory available, you can instead implement in a streaming approach by using the `stream_contexts()` generator function to access the data; this lets you iterate through the data from disk, one vector at a time, without putting everything into memory. You can see its use in the loading function. (You could also alternatively use a key-value or other type of database, but that’s too much work for this assignment.)

# %%
import distsim; reload(distsim)
word_to_ccdict = distsim.load_contexts("nytcounts.4k")
# print word_to_ccdict.values()[:5]
similarity_dic = distsim.construct_simliarity_dic(word_to_ccdict)
# top_50 = similarity_dic.items()
###Provide your answer below; perhaps in another cell so you don't have to reload the data each time
# Out:
# file nytcounts.4k has contexts for 3648 words
# https://t.co/3ooopaeluh 1.0
# co/avbcg1csrn 1.0
# https://t.co/im6rszjgah 1.0
# gah 9.0
# thoug… 2.0
# sonja 1.0
# woods 12.0
# spiders 3.0
# hanging 42.0
# woody 6.0
# comically 2.0
# 😂😂😂💀💀 1.0
# https://t.co/i7bzzkrsel 1.0
# canes 20.0
# https://t.co/xk5rapwbbh 1.0
# igual 2.0
# https://t.co/vhfstv4s89 1.0
# https://t.co/jnyhjfwbi6 1.0
# crossbar 1.0
# https://t.co/pwkzesffos 1.0
# tomorrow😍#gratitude 1.0
# ...'' 1.0
# giveaway💍 2.0
# https://t.co/gkkfqlakbt 1.0
# pangpang 1.0
# https://t.co/w8kukyvweg 1.0
# ;!! 2.0
# girlfrie… 1.0
# 💞💞💞😚😚😚 1.0
# screaming 49.0
# beyon… 1.0
# discribes 1.0
# https://t.co/vynrsnsmhd 1.0
# https://t.co/f3cyvxipne 1.0
# vibrational 1.0
# wooden 4.0
# soirées 1.0
# vibes😌 1.0
# viable 7.0
# https://t.co/8wipznjtga 1.0
# crotch 2.0
# https://t.co/z7tvvwojol 1.0
# light… 1.0
# 자주 1.0
# 🙂🙂🙂 5.0
# trumpette 1.0
# 27% 3.0
# while😍 1.0
# snuggles 2.0
# snuggler 3.0
# error\ 3.0
# https://t.co/f0oxigrknl 1.0
# 270 1.0
# cantando 2.0
# https://t.co/udpxqoh4tb 1.0
# prostaffers 1.0
# https://t.co/gqhohlco6a 1.0
# consenting 2.0
# 😘✨ 1.0
# snuggled 14.0
# errors 6.0
# starboy 5.0
# 🍄🍄🍄 3.0
# https://t.co/g2ncqtz7cp 1.0
# \n\nnow 14.0
# https://t.co/ix8y0j6c8a 1.0
# https://t.co/dgqwjuihrc 1.0
# designing 7.0
# replaced 19.0
# ✅💯 1.0
# 🏃🏽‍♀️❤ 1.0
# dayumm 1.0
# kid\ 2.0
# brainwashed 82.0
# camren 3.0
# 👊🏃💪#digdeepboco 1.0
# over/under 1.0
# we'r… 2.0
# sexua 1.0
# affiliated 2.0
# https://t.co/sm1b36pbkq 1.0
# cle… 1.0
# https://t.co/ue00acjsaz 3.0
# jasmineeeeeee 1.0
# kids 597.0
# it❤️ 2.0
# uplifting 36.0
# let'sbe 1.0
# kidz 1.0
# controversy 6.0
# kidd 3.0
# 😂😂😌😉 1.0
# -follow 3.0
# neurologist 1.0
# spotty 1.0
# https://t.co/7btlxdj3cn 1.0
# kido 1.0
# nlying 1.0
# https://t.co/dm5c3y55wu 7.0
# projection 2.0
# sm❤️❤️❤️❤️ 1.0
# https://t.co/ndc78y9ngy 1.0
# https://t.co/xif6bt7k2t 1.0
# https://t.co/rfgdipswta 17.0
# 🌹🌹- 1.0
# stern 1.0
# https://t.co/ahygcu6njs 2.0
# dnd 2.0
# agassi 1.0
# dna 4.0
# dnc 48.0
# insecurity 5.0
# https://t.co/s8lnpnlpwp 1.0
# kazuha 1.0
# https://t.co/43qjl5f0q1 1.0
# dnt 25.0
# smil… 1.0
# https://t.co/ohus6f9iqz 2.0
# dns 1.0
# distortions 1.0
# sermons 1.0
# boobage 1.0
# 🙌🏽🙌🏽… 1.0
# populations 1.0
# nakaya 1.0
# yahoo 4.0
# https://t.co/q9ismdu8nx 1.0
# https://t.co/65dxrbum6s 1.0
# b.i. 3.0
# echelon 1.0
# https://t.co/ruvdwpzpty 1.0
# intake 2.0
# morally 16.0
# storms⛈💙 1.0
# https://t.co/dctojxnglk 1.0
# 😍😘💕😘💕😘💕😘 1.0
# benvolio 1.0
# thepiugformemes 1.0
# https://t.co/movjiqv4yg 1.0
# day☺️roose 1.0
# https://t.co/norrcwknzy 1.0
# you😭❤ 2.0
# wana 31.0
# wang 2.0
# wand 8.0
# pints 2.0
# wank 2.0
# eczema 2.0
# 2015) 2.0
# want 3748.0
# pinto 1.0
# cocksucker 4.0
# https://t.co/z8zbyrkdpa 1.0
# https://t.co/fl4w7attnk 1.0
# syphilis\ 1.0
# travel 183.0
# https://t.co/83qfns6jf5 1.0
# copious 1.0
# yesterday❓😩 2.0
# lindsey 8.0
# few… 1.0
# https://t.co/3sxgdtqto8 1.0
# 🤕🙂 1.0
# https://t.co/bacfrgoqdi 1.0
# https://t.co/0ga3a82vrj 1.0
# https://t.co/hhwfyuy8j2 1.0
# https://t.co/oxi2rv5mal 1.0
# aches 7.0
# https://t.co/rnrccsfbep 1.0
# dinosaurs 1.0
# wrong 10151.0
# seulement 1.0
# sentencing 2.0
# 💙🎵🐻😎🐯 1.0
# -kaito 1.0
# 🤗🤗🤗🤗🤗🤗🤗 1.0
# https://t.co/klvtyfdro7 1.0
# delusional...you're 1.0
# https://t.co/yaotgpmkxu 1.0
# https://t.co/uyih6yebwd 1.0
# shreya 1.0
# https://t.co/6mz4imyfwt 1.0
# gardos 1.0
# https://t.co/zabaab4ykr 1.0
# smashers 1.0
# ❤⌛️ 5.0
# welcomed 5.0
# welcomee 1.0
# concurrence 1.0
# https://t.co/vqeuat8zxj 1.0
# benefited 2.0
# https://t.co/f2ldnyb9to 1.0
# foreal 3.0
# https://t.co/y2wt8mzzhw 1.0
# welcomes 2.0
# fir 5.0
# https://t.co/ozjqc8… 1.0
# fit 100.0
# https://t.co/evcuruvtvx 1.0
# fiz 5.0
# bringing 94.0
# fix 188.0
# folate 1.0
# https://t.co/jzyepixpwe 20.0
# fic 18.0
# \"you're 71.0
# fig 2.0
# fii 1.0
# fin 1.0
# fil 27.0
# zucker 1.0
# welcome) 1.0
# shi… 8.0
# vouchers 13.0
# ankou 1.0
# narcoterrr 1.0
# effects 31.0
# hood🔥 1.0
# hwasa 3.0
# 😍❤️🐶 1.0
# 24/7like 1.0
# https://t.co/3lql1hidir 1.0
# x2000 1.0
# bff5 2.0
# https://t.co/048wkcvdvw 1.0
# https://t.co/x9qszi89od 1.0
# timeout 6.0
# ingrid 2.0
# andanana 1.0
# https://t.co/1qlsxd4glj 1.0
# https://t.co/bevlrvuuob 1.0
# https://t.co/rf3nvgnvxf 1.0
# sya 1.0
# https://t.co/qpfktwduvo 1.0
# wednesday 122.0
# https://t.co/h6wzmpuk8a 1.0
# https://t.co/0mzpnmrgzq 4.0
# tarasenko 1.0
# https://t.co/xvtahgzrmt 13.0
# https://t.co/5wavusuyxm 1.0
# impossible 92.0
# 2day 24.0
# https://t.co/pjm3yhmtxi 1.0
# https://t.co/fxl3zr9pzh 1.0
# 3years 2.0
# https://t.co/pkps2msjvv 1.0
# self- 1.0
# cld… 1.0
# njalo 1.0
# https://t.co/4fggnos5e9 1.0
# chokers 1.0
# syd 20.0
# tho😍💦💦 1.0
# adapt 53.0
# anjoooo 1.0
# gwangjoon 1.0
# https://t.co/vxsx3lg1r8 1.0
# wonderbread 1.0
# back🌙🔙 5.0
# sheep 11.0
# abbott 5.0
# plis❤ 1.0
# https://t.co/mcwhar8cdd 1.0
# https://t.co/hwdplnfpzu 1.0
# https://t.co/6qiqy1ts7n 1.0
# stereotypical 3.0
# co/yltwqle9hq 1.0
# estimate 3.0
# ugghhh 2.0
# gameplay 11.0
# https://t.co/uhwiacqjlz 1.0
# grace😘 1.0
# sickeningly 1.0
# co/mnikqkfklx 1.0
# 🤔orange 1.0
# https://t.co/gvjxibdcrp 1.0
# self~ 1.0
# disturbed 5.0
# https://t.co/fqzq3jafc8 282.0
# shrugged-off 1.0
# https://t.co/obqewaujwr 1.0
# https://t.co/aedrtx3aaj 5.0
# 🏄🏼 1.0
# https://t.co/br8rm7sidp 1.0
# loook 2.0
# https://t.co/5iqy47fj0l 1.0
# loool 8.0
# https://t.co/ajepjajh3l 1.0
# dgu 2.0
# https://t.co/g392dcrs5t 1.0
# douglasville 7.0
# knight 13.0
# faaaarrrr 1.0
# https://t.co/ybrdbktetb 1.0
# witzenhausen 1.0
# https://t.co/vl4j9cxvpx 1.0
# olds 8.0
# renovated 1.0
# jugg 1.0
# https://t.co/d8yyoshqrh 2.0
# https://t.co/nvtzanw7pv 1.0
# posty❤️ 1.0
# https://t.co/v78pw189i9 1.0
# https://t.co/flo08dn6ry 1.0
# needed 203.0
# master 24.0
# https://t.co/fjqa4uvcr9 1.0
# https://t.co/6hkdqunvsl 3.0
# genesis 3.0
# caitlyn 5.0
# rewards 11.0
# evi… 5.0
# https://t.co/jra1u9eqag 1.0
# ✨👠 1.0
# jerkoff🖕🏼 1.0
# yield 4.0
# https://t.co/bnbfslahqm 1.0
# swish 2.0
# cravetaaaaayy 2.0
# positively 17.0
# ahmed 2.0
# mycoworkers 1.0
# duckworth 3.0
# https://t.co/jhyo5ynrhy 1.0
# anniversaries 1.0
# 💗:') 1.0
# https://t.co/h6cmf0mgtn 1.0
# ♡♡♡♡♡ 1.0
# stl/was 1.0
# shouldn… 1.0
# blackbag 1.0
# herd… 1.0
# feeling 1097.0
# 😭😩✊🏾❤️❤️❤️ 1.0
# https://t.co/0dtgcns258 1.0
# 😭😕 1.0
# yeezys 6.0
# wizards/warriors 2.0
# really.. 1.0
# https://t.co/iw2rjdtfgh 1.0
# 😭😘 2.0
# 😭😅 2.0
# 😭😁 1.0
# pandemics 1.0
# 😭😂 30.0
# 😭😍 79.0
# 😭😊 1.0
# affairs 55.0
# wholesome 15.0
# https://t.co/lzinqvo7am 1.0
# 😭😹 1.0
# 😭😻 2.0
# https://t.co/qujpjieyva 1.0
# self💗💗💗 1.0
# deepthroating 2.0
# sh*t. 1.0
# 😭😭 79.0
# ken_dunn 1.0
# ke$ha 1.0
# 😭😩 11.0
# kremlin 1.0
# 😭😫 1.0
# rhcp 4.0
# 45th 6.0
# https://t.co/ygj4irysrb 2.0
# https://t.co/opf2tplzwv 1.0
# cinematic 11.0
# resonates 3.0
# https://t.co/ry9lgda8qn 1.0
# simplify 3.0
# creates… 1.0
# https://t.co/bxekvzfgku 1.0
# resonated 2.0
# dailey 1.0
# https://t.co/mdzd8dgint 1.0
# https://t.co/uggdclfslz 1.0
# maji 1.0
# https://t.co/pll2xfetxv 1.0
# https://t.co/piiydddmsp 5.0
# sandoval 1.0
# https://t.co/r6gbrzqkdz 1.0
# https://t.co/y4yxyskbu6 1.0
# tech 43.0
# fugitives 1.0
# doesn’t 111.0
# purged 1.0
# trollers 2.0
# saying 673.0
# 💜💜💜😍😍 1.0
# kitakits 1.0
# voice😍💕😚 1.0
# tempted 6.0
# https://t.co/omn5ctigq5 1.0
# https://t.co/remkawzhfu 1.0
# bullshitted 2.0
# clicked 9.0
# ajayi 1.0
# nontrinitarian 1.0
# https://t.co/c2ez9y2kkx 1.0
# nerds\ 1.0
# https://t.co/spd6xrnrod 1.0
# lepidoptera 1.0
# bullshitter 2.0
# *sighs* 1.0
# hoeing 6.0
# https://t.co/nitsjeqjxq 1.0
# plate 20.0
# https://t.co/vljww2juco 1.0
# https://t.co/zgrnbqv7kz 1.0
# https://t.co/g3qfmqnmoz 1.0
# plato 4.0
# plath 1.0
# ldn 1.0
# hellup 1.0
# yersel 1.0
# altogether 3.0
# slidin 2.0
# https://t.co/xqfyqchr2m 1.0
# naesous 1.0
# superfamily 1.0
# jaguar 1.0
# seuss 10.0
# gtoup 1.0
# distracting 6.0
# nicely 13.0
# https://t.co/jtqpytkf2a 1.0
# pre-sxsw 1.0
# (@courier_5) 1.0
# patch 11.0
# https://t.co/6xcdbngmrw 1.0
# 10mm 1.0
# https://t.co/txtm3b5hp4 57.0
# https://t.co/v32kemyocj 1.0
# imagine\n\njacob 13.0
# lot\ 1.0
# 🍑🏆 3.0
# pinot 5.0
# you😘❤️ 1.0
# profoundly 3.0
# https://t.co/tcdksifhqk 1.0
# https://t.co/eaqzg67e9x 11.0
# pinoy 1.0
# http://t.co/mltc… 1.0
# hurts😭 1.0
# ”ht… 1.0
# lots 375.0
# lotr 2.0
# irs 2.0
# xvi 2.0
# irk 2.0
# irl 17.0
# https://t.co/m1fgfywifx 1.0
# srinivas 8.0
# amatter 1.0
# https://t.co/eoemlfpuv7 1.0
# https://t.co/xtbkbd7rer 1.0
# discipline 4.0
# https://t.co/uhza3phm4o 1.0
# extend 7.0
# nature 72.0
# fruits 19.0
# pentheon 1.0
# extent 23.0
# https://t.co/6tdgwqz9j2 1.0
# miyako 2.0
# dog's; 2.0
# +11 1.0
# punch-you-in-the-gut 1.0
# https://t.co/jauzs8djm5 1.0
# xv2 1.0
# deescalating 1.0
# -rick 1.0
# 6526262 1.0
# https://t.co/1qxn4k7l1n 1.0
# lookin 132.0
# https://t.co/fvsmgiggkt 30.0
# lookie 1.0
# https://t.co/gkww7temw0 1.0
# waiting🙄 1.0
# twenty-three 1.0
# 🖐🏻on 1.0
# 🙏💕💕 1.0
# told… 1.0
# https://t.co/5eqwwy3ark 1.0
# gopher 1.0
# okkkk 2.0
# gilinsky 7.0
# niya 1.0
# https://t.co/ndgh3l90sy 1.0
# brindle 1.0
# 🍷😝 1.0
# smackdown 41.0
# https://t.co/dmllj05yj9 1.0
# mucy 1.0
# integrate 1.0
# fri 10.0
# fro 5.0
# frm 10.0
# . 65764.0
# https://t.co/ieymxg33oo 4.0
# withtrump 1.0
# much 7442.0
# 😫😍 3.0
# dems… 45.0
# https://t.co/cafozairyn 1.0
# fry 2.0
# https://t.co/tswnx1idaa 3.0
# obese 3.0
# apples\ 1.0
# https://t.co/iru018xnmg 1.0
# https://t.co/bnpeqcj0qi 4.0
# spit 10.0
# *faints* 1.0
# https://t.co/tigegh3onl 2.0
# jeon 4.0
# https://t.co/9sijrqwqa3 1.0
# https://t.co/dnmguasrjx 1.0
# https://t.co/eb7uysbnuz 1.0
# doubts 4.0
# https://t.co/jghfejgm9o 1.0
# spin 39.0
# kentucky-vandy 1.0
# wildcat 1.0
# 😩😭💖 1.0
# https://t.co/agkvrvdr6g 1.0
# mesmerising 1.0
# \ntrump 1.0
# want/need/feel/see/like 1.0
# non-tenured 1.0
# https://t.co/xa0s5dwmty 1.0
# 💞#nerve 1.0
# song☺️☺️☺️ 1.0
# 😔🙌🏽 1.0
# majid 2.0
# https://t.co/98ypc2c64p 1.0
# man😂 1.0
# riparian 1.0
# man😍 1.0
# kohn 2.0
# embargos 1.0
# conditioned 4.0
# https://t.co/i6jecktess 3.0
# 🛌❣️❣️ 1.0
# https://t.co/wrhnxnlwpj 1.0
# conditioner 2.0
# https://t.co/mknm8gzg5a 2.0
# memorial 1.0
# memoriam 1.0
# man😭 1.0
# https://t.co/pwwzmervuo 2.0
# honk 2.0
# spews 11.0
# xxoo 1.0
# unadded 1.0
# man😿 1.0
# 😂💁🏽 1.0
# https://t.co/ihfgza55rp 1.0
# 🔥@justinbieber🔥 1.0
# https://t.co/9gdrnfz7co 1.0
# https://t.co/gi87dx0ack 1.0
# https://t.co/lmithtra3i 1.0
# qdoba 3.0
# 🙄it 1.0
# engagement-not 2.0
# i'd... 1.0
# 76-78 1.0
# "who 1.0
# zoomin 1.0
# https://t.co/p2xtsftsko 1.0
# https://t.co/qpgaqzb5lb 1.0
# always😍💜🎉🎊🎈🎂 1.0
# https://t.co/1zrp8dfmh3 1.0
# ye… 4.0
# nibba 1.0
# https://t.co/ppyuhswe4y 1.0
# https://t.co/tnx8jjejjc 1.0
# stillness 1.0
# academia 2.0
# lonelier 1.0
# nomore 9.0
# corporate 32.0
# massaging 3.0
# https://t.co/ltiapwbco9 1.0
# ffcjdfj 1.0
# foreigners 10.0
# https://t.co/2zbcpndizu 1.0
# golden 68.0
# https://t.co/v5u5drafke 1.0
# https://t.co/xvh9uhzntx 1.0
# prometh 1.0
# ???! 1.0
# 🎉😘@carla27noel 1.0
# ???? 91.0
# 💜🐶 1.0
# https://t.co/nqivkdwivk 1.0
# garciainstagram 1.0
# bribes… 2.0
# stna 1.0
# hah 10.0
# hai 10.0
# haj 1.0
# danmachi 1.0
# hal 4.0
# ham 11.0
# duffer 1.0
# haa 1.0
# hab 1.0
# had 2318.0
# https://t.co/gzp3ajrlx1 1.0
# haf 1.0
# hag 4.0
# https://t.co/hasl6sc8d6 1.0
# mcnamara 1.0
# https://t.co/y3vfa7k6wu 1.0
# https://t.co/rorjo1szzy 4.0
# hap 2.0
# shiii 2.0
# har 4.0
# has 3087.0
# hat 123.0
# https://t.co/ryhs1lfrdi 1.0
# hav 9.0
# muckers 1.0
# eldery 1.0
# municipal 1.0
# https://t.co/8qux0s9obk 1.0
# elders 4.0
# https://t.co/cpsobk4y6n 1.0
# https://t.co/xbds2jlvjw 1.0
# https://t.co/9vrexv7gjh 1.0
# unequivocally 1.0
# indicative 3.0
# https://t.co/va7vonlmwf 1.0
# meatloaf) 1.0
# https://t.co/s1poymxne4 1.0
# 12:31 1.0
# 12:30 1.0
# ukitake/bleach 1.0
# https://t.co/eox58y5crq 1.0
# https://t.co/k7xapjtg1b 1.0
# 💙😇🎭 1.0
# https://t.co/ed8b9arky1 1.0
# https://t.co/4gooiawaez 1.0
# seme 1.0
# ❤😢🙏 1.0
# crowd 71.0
# crowe 1.0
# czech 2.0
# mosques 10.0
# crown 8.0
# is…not 1.0
# captive 1.0
# that...he 1.0
# ☆* 3.0
# \nit 4.0
# botton 1.0
# bottom 56.0
# lockdown 3.0
# point… 1.0
# https://t.co/otouxgruqb 3.0
# mucjh 2.0
# raylan 1.0
# https://t.co/dsmv0nw9xz 1.0
# completly 1.0
# doesn't; 1.0
# 8yr 1.0
# ▪i 2.0
# anchor… 1.0
# https://t.co/bl0gx1scat 1.0
# idiot\"\ndon't 1.0
# https://t.co/7lv0egk3c7 1.0
# doesn't. 15.0
# doesn't, 1.0
# ❤️🌹 2.0
# ❤️🌶 1.0
# doesn't! 1.0
# people😊 1.0
# people😴 1.0
# benches 2.0
# https://t.co/4mswoho0ho 1.0
# https://t.co/yidfynplob 1.0
# 🙌🏾👏🏾everything 1.0
# acog 1.0
# sequin 3.0
# benched 3.0
# https://t.co/qadtuvcjec 1.0
# https://t.co/f2yxu13wvw 1.0
# https://t.co/qfqsw4chcp 1.0
# lemmings 1.0
# dyson 1.0
# honeymoon 12.0
# https://t.co/mlou3vw4wi 1.0
# boi👌🏼 1.0
# *waits 1.0
# mangos 1.0
# https://t.co/mvpipwvhb4 1.0
# shoots 10.0
# fabric 10.0
# birthday♥︎ 1.0
# https://t.co/ti9ntefon5 1.0
# actions… 3.0
# raped 14.0
# https://t.co/wsg8glhogn 1.0
# grasping 11.0
# shoot\ 1.0
# rapes 1.0
# 💪🏾💯 3.0
# avocados 7.0
# https://t.co/apthyfvwvb 1.0
# dnp 1.0
# https://t.co/h9vkqbuhav 1.0
# perfumes 3.0
# https://t.co/gbxm2j5lzp 1.0
# budaj 1.0
# decide… 2.0
# perfumed 1.0
# https://t.co/ryp3vppei1 1.0
# https://t.co/ls7cdiv7qg 1.0
# humble\ 1.0
# xxxibgdrgn 1.0
# congratulations 111.0
# https://t.co/bqzo3cfgw0 1.0
# humbled 4.0
# r-pa 1.0
# martial 3.0
# non-discrimination 1.0
# westallen 11.0
# https://t.co/sortlnskgy 1.0
# nicest 5.0
# ju… 7.0
# https://t.co/kqxumg6vf1 13.0
# tannehill 1.0
# creuset 1.0
# https://t.co/8… 3.0
# ti… 13.0
# ❤️🐕rip 1.0
# https://t.co/4kjsdl5qk7 1.0
# https://t.co/8l5fqkoffx 1.0
# https://t.co/z2fb3mk4vv 1.0
# moderns 1.0
# https://t.co/0dgtyfdtp5 1.0
# https://t.co/m2o0… 2.0
# https://t.co/hbvsl6redh 1.0
# lylas 1.0
# htown 1.0
# cambodia 1.0
# https://t.co/fxtfg7r9gn 1.0
# currington 10.0
# ya❤️🎉 1.0
# https://t.co/nrbafnrdcy 1.0
# https://t.co/y988vn8lb4 2.0
# re-watched 1.0
# ‼️💯🙈🙊\ 1.0
# https://t.co/quh6smwdh0 1.0
# https://t.co/gdhkk89qv0 1.0
# co/xj80wgn8gu 1.0
# hawked 1.0
# https://t.co/h1p5x0rw2x 2.0
# fight… 1.0
# acquaintance 2.0
# smelling 22.0
# nightblood 1.0
# allkpop-_- 1.0
# work/school 1.0
# twins'\n\ngrayson- 2.0
# loren 1.0
# https://t.co/capxkqwyxj 1.0
# shootout 3.0
# https://t.co/founhabhoc 1.0
# https://t.co/5kptzqutqk 4.0
# margielas 1.0
# https://t.co/srdzllkai5 1.0
# 😍😍😍🐹✨ 1.0
# https://t.co/yef0c4oyzc 1.0
# tryouts… 1.0
# https://t.co/yhaakcyylm 1.0
# https://t.co/gwkzpilhck 1.0
# steelhead 1.0
# https://t.co/1ae5eu628l 1.0
# https://t.co/io8hcypei3 1.0
# childs 5.0
# chain 17.0
# whoever 99.0
# https://t.co/cchtkhifcu 1.0
# https://t.co/lvg0skqixv 1.0
# alon… 2.0
# memories🎈❤️party 1.0
# https://t.co/mfkf1dikc8 1.0
# eternally… 1.0
# annnnnd 2.0
# https://t.co/tvc9xr6l1r 1.0
# co/adnlggwraz 1.0
# chair 38.0
# ❤️💓❤️ 1.0
# https://t.co/mr0q6rik4x 1.0
# https://t.co/wfgze7bibx 3.0
# https://t.co/cf9kprrupa 1.0
# https://t.co/fewueclbt5 1.0
# freelance 2.0
# child\ 1.0
# lara 2.0
# m3iske 1.0
# https://t.co/lrh323hta3 1.0
# balled 2.0
# https://t.co/tyt4iivanz 1.0
# https://t.co/1rf4t1tirj 1.0
# foxyfayette 15.0
# macho 16.0
# oversight 11.0
# machi 2.0
# tenacious 1.0
# https://t.co/zp3q6eqdh0 1.0
# https://t.co/ekq02fqzhw 1.0
# paychecks 1.0
# jerk 34.0
# jere 1.0
# ❤️❤️❤️❤️❤️🍿🍿 2.0
# https://t.co/16fxfwgejc 2.0
# nguvu 1.0
# https://t.co/bbuozuh7ex 1.0
# embark 3.0
# 🤦🏾‍♀ 1.0
# locked 23.0
# minuta 1.0
# exact 19.0
# minute 174.0
# https://t.co/gr90utisb1 1.0
# https://t.co/xmp13ammfr 1.0
# https://t.co/bw3vpgojze 1.0
# 🙌🏿❤️ 1.0
# homebody 4.0
# cameo 2.0
# skewed 2.0
# yndu 2.0
# much❤❤ 1.0
# satrughan 1.0
# hozier 2.0
# https://t.co/z8nqs… 1.0
# https://t.co/bvezuidpwb 1.0
# https://t.co/b8i5tucgsc 3.0
# buud 1.0
# xenophobe 3.0
# https://t.co/zxgqon8qro 1.0
# https://t.co/btwcdk5jnx 2.0
# hindered 1.0
# bars💏💯🤘🏽 1.0
# unrt 1.0
# anti-media 1.0
# https://t.co/t7aft5gvks 1.0
# life☺️❤️ 1.0
# corazon 1.0
# “how 1.0
# celebrated 18.0
# shuttttt… 2.0
# https://t.co/hko2ifgqgg 1.0
# tirefire 1.0
# https://t.co/tkwg2klt4q 1.0
# bleesed 1.0
# celebrates 24.0
# sanghi 3.0
# unintentionally 3.0
# https://t.co/69ghzilkw3 1.0
# drafted 4.0
# https://t.co/zlvqremgks 1.0
# https://t.co/pehdq1ifxp 1.0
# oldies 1.0
# me🤗 1.0
# honour 4.0
# me🤔 1.0
# plucking 1.0
# https://t.co/7gfqe1sfot 1.0
# blogtalk 1.0
# address 333.0
# chit-chat 7.0
# miiverse 1.0
# $80 1.0
# co/eydqld1aez 1.0
# https://t.co/0czhhtihfv 1.0
# benson 1.0
# guys😭let 1.0
# penguin 1.0
# -caramel 3.0
# -trump\n\ntweet 1.0
# impacted 2.0
# queue 3.0
# secnod 23.0
# you💗💗 4.0
# https://t.co/g36ykazb2o 1.0
# stay👏 1.0
# https://t.co/unknh59n36 1.0
# much💜💜👑💙 1.0
# https://t.co/kwglha96ph 1.0
# 😂👎🏽 1.0
# bigat 1.0
# https://t.co/1p6kbqzanb 1.0
# ufp 1.0
# randoms 4.0
# fakers 2.0
# soul 485.0
# nall 2.0
# https://t.co/6lgeyfekca 1.0
# fakery 1.0
# opposes 34.0
# https://t.co/qlwvcpswla 1.0
# toxoplasmosis 1.0
# https://t.co/ees8dafkcx 1.0
# https://t.co/ynuh9yuytr 2.0
# gulags 1.0
# oduya 25.0
# 🙄🔫 1.0
# opposed 40.0
# cats\ 3.0
# https://t.co/xyzdkkyylq 1.0
# 'dude, 1.0
# https://t.co/vwysszf2rj 1.0
# day💖 3.0
# day💐 1.0
# lmaooooooooooooooo 1.0
# https://t.co/ii0qbtdnf8 1.0
# day💓 2.0
# day💜 3.0
# is😊i 1.0
# ooooooo 2.0
# wvw 1.0
# https://t.co/9wdqrlkeam 1.0
# wvu 1.0
# consoles 3.0
# okur 1.0
# ctto 10.0
# chestbursting 1.0
# https://t.co/awdkgaehor 1.0
# https://t.co/l4l3ccsxa4 1.0
# rebounding 2.0
# https://t.co/b7q8cndfpc 1.0
# 😠👊 1.0
# https://t.co/2bsdengupp 1.0
# galila 1.0
# https://t.co/xvhtsqcm1i 1.0
# day💡 7.0
# following 216.0
# day💯 2.0
# menegakkan 1.0
# https://t.co/n54feqgo6i 1.0
# https://t.co/bu3bsqklmx 1.0
# https://t.co/mhlrkpnpfg 1.0
# decision… 1.0
# gratitude… 1.0
# listen~ 1.0
# https://t.co/7yjb1jkazh 1.0
# week-end 1.0
# listens 12.0
# https://t.co/ukphvirpkl 1.0
# thanking 6.0
# ounce 16.0
# too😏😉 1.0
# listen- 2.0
# harmos 2.0
# bish 6.0
# https://t.co/mulfmgdolo 1.0
# cuhz 1.0
# sour 31.0
# fueled 7.0
# siarra 1.0
# tourney/provincials 1.0
# sfwsbp 1.0
# gab😉💕 1.0
# https://t.co/6rup8mxdze 1.0
# surfing 2.0
# bi… 11.0
# https://t.co/ohl47xihbn 1.0
# https://t.co/aexxkvp… 1.0
# ❤️️💯✨⚾️ 1.0
# https://t.co/qkeenftsya 1.0
# direction\n\n#tntultimateresbakday3 1.0
# https://t.co/widmkran46 1.0
# don't\n- 1.0
# nick\n#thebachelor 1.0
# webpage 1.0
# 20:736 1.0
# professors 14.0
# https://t.co/aeszz0boz5 1.0
# https://t.co/legvtd15qt 1.0
# overlord 4.0
# jib 1.0
# girl👩‍❤️‍💋‍👩👩‍❤️‍💋‍👩👩‍❤️‍💋‍👩👩‍❤️‍💋‍👩 1.0
# jia 1.0
# jin 36.0
# jio 2.0
# jim 38.0
# tull 1.0
# https://t.co/71r6rk8f9a 1.0
# 🎂🙌 1.0
# brit👯💖 1.0
# thine\ 1.0
# https://t.co/4n9xhutw9s 1.0
# no-brainer 1.0
# apron 2.0
# \n*moves 1.0
# dead\ 2.0
# https://t.co/snb1ejnbd7 1.0
# 45,372 1.0
# 45,377 1.0
# https://t.co/xbwjgrstpl 1.0
# damnnnn 1.0
# probabl… 1.0
# did\ 4.0
# https://t.co/xfl0b7pxe9 1.0
# things:\n\ndon't 1.0
# \ 10866.0
# https://t.co/ifpc9t0be9 1.0
# deadz 1.0
# didi 3.0
# didu 1.0
# monet\n 1.0
# tongues* 1.0
# https://t.co/vyoqrvmuea 1.0
# quarter 31.0
# quartet 1.0
# padmé 2.0
# salado 1.0
# ooomf 1.0
# https://t.co/m4tqgfp9ti 1.0
# bursting 2.0
# https://t.co/0acvygt9ki 1.0
# miio 1.0
# https://t.co/pfsge43it6 1.0
# exo'rdium 1.0
# fallin 34.0
# h17bd 2.0
# feeeel 1.0
# entering 8.0
# newsradio 2.0
# bachelor/bachelorette 1.0
# https://t.co/pfzm36ahge 1.0
# two-piece 1.0
# 1172 1.0
# https://t.co/a0clunwtrr 1.0
# https://t.co/alcyq3lxm4 1.0
# skinny\ 1.0
# seriously 394.0
# https://t.co/8lxflwln4a 2.0
# instagram🚨 1.0
# seriouslt 1.0
# 😳😳😤😤😤🙏🏽🙏🏽💯🔫🔫😳👌🏼👌🏼👏🏼👏🏼 1.0
# breakkkkkk 1.0
# plisetsky 40.0
# ⚽️☺❤❤ 1.0
# incentives 3.0
# https://t.co/cycvywunbn 1.0
# 😍💕✊✊✊✊✊✊ 1.0
# https://t.co/1jtq3ie8kb 1.0
# crazies 1.0
# crazier 2.0
# https://t.co/ucdaipe3tf 1.0
# grandma 57.0
# https://t.co/mnaab20vct 1.0
# https://t.co/a2yvyz826e 1.0
# hear❣ 1.0
# https://t.co/sp47xabhya 1.0
# 😊😊😊😊😊😊😊 1.0
# fac… 1.0
# modest 12.0
# benching 1.0
# 😂💃🏾 1.0
# https://t.co/jbfoeakkmm 1.0
# f-bomb 1.0
# 💜🇺🇸 1.0
# —has 1.0
# couldn't. 1.0
# hemorrhoids 1.0
# anymore* 1.0
# https://t.co/pupw6yfrrv 1.0
# krystlelites 2.0
# spoken 24.0
# parkinson 1.0
# https://t.co/tff449ldhc 1.0
# ✨❤️ 1.0
# hombres\ 16.0
# spokes 1.0
# https://t.co/ar5mg4jpoh 1.0
# it😘@forever_imb 1.0
# https://t.co/zjghfps9ze 1.0
# person🙃 1.0
# person🙄 1.0
# https://t.co/kseilezeba 1.0
# https://t.co/rm9rjk0gnw 1.0
# idealistic 12.0
# https://t.co/wrchry4ypi 1.0
# someone/something 1.0
# lingering 2.0
# 🙄😩😂 1.0
# https://t.co/ks5ur136f6 1.0
# ableton 1.0
# derangement 1.0
# 🏆👌🏼 1.0
# snatch 9.0
# almond 7.0
# https://t.co/ma7ze1jzxt 1.0
# diet/exercise 1.0
# https://t.co/2eakr7hxtp 1.0
# famine 4.0
# 💗💕💖 1.0
# ic 3.0
# https://t.co/to3hrari4j 1.0
# crossroads 13.0
# rehab 5.0
# mv\ngrammys\nru 1.0
# anymore\ 16.0
# medicates 1.0
# https://t.co/nk2z… 1.0
# https://t.co/rh5jyqy48a 1.0
# https://t.co/sukwepczja 1.0
# emen 1.0
# https://t.co/5xf32psmzu 1.0
# https://t.co/hkbtxbtav9 1.0
# https://t.co/xam78l09yt 1.0
# turned 145.0
# 🎼🎧 1.0
# jewels 2.0
# auroras 1.0
# pateets 1.0
# sweetsmelling 1.0
# booty\ 1.0
# turner 5.0
# blu… 7.0
# https://t.co/ditnne2hnk 1.0
# zoe 5.0
# fashionable 5.0
# zoh 1.0
# coliseum 1.0
# co/njbgh5x7oi 1.0
# dilutions 1.0
# “greater 4.0
# zoo 8.0
# https://t.co/1bit5w12zi 1.0
# zot 1.0
# zou 1.0
# https://t.co/qhoasa… 2.0
# fashionably 1.0
# ahhhhhhh\ 1.0
# pimple 5.0
# opposite 54.0
# rudeee 1.0
# spewing 35.0
# touch\ 8.0
# https://t.co/owxm7obtss 1.0
# whtevr 1.0
# https://t.co/m0x8uouscu 1.0
# https://t.co/5mhixfoydt 1.0
# whhyyyy 1.0
# https://t.co/8ks82bqd5c 1.0
# baby❤️❤️ 1.0
# touchy 2.0
# psat 3.0
# touche 1.0
# https://t.co/1pg4iwwi0w\ 1.0
# jittery 2.0
# steve- 1.0
# 😔… 1.0
# ooohhh 1.0
# https://t.co/k9yljx8m85 1.0
# https://t.co/ltj59txmmn 1.0
# https://t.co/vdzwsratd2 1.0
# https://t.co/5o24fnuyi8 1.0
# https://t.co/vbfmj1dhfq 1.0
# friction 1.0
# https://t.co/prnpepyrsx 1.0
# inconsistent 10.0
# gasgang 3.0
# imagined 73.0
# ~~~~ 3.0
# *flashbacks 1.0
# https://t.co/yfchfjbzsd 1.0
# https://t.co/l4rbo2im94 1.0
# assing 1.0
# 10mins 2.0
# https://t.co/9cbvi7uw7q 1.0
# 👼🏻🎈 1.0
# stoicism 1.0
# rejoices 1.0
# etcetera 1.0
# singer-songwriter 1.0
# grades\ 2.0
# https://t.co/afrx1mj8fg 1.0
# pimp 7.0
# https://t.co/omhuqruopf 1.0
# texting😕 1.0
# tiku 1.0
# self-promotion 1.0
# disc… 1.0
# hahvahd 1.0
# durmo 1.0
# tika 1.0
# hotness 2.0
# 💞💖❤️ 1.0
# twice… 1.0
# 👌🏻✌🏼 1.0
# eriksen 1.0
# https://t.co/wzbnqxqfl9 8.0
# 🦋without 1.0
# https://t.co/xtjfyjwbyg 1.0
# https://t.co/3crrgmgqen 1.0
# high… 1.0
# defensively 5.0
# dexter 8.0
# https://t.co/j88tdukpaf 1.0
# https://t.co/gafgtdf6a3 1.0
# o'donnell\" 1.0
# president...i'm 1.0
# sponsorship 1.0
# vaccines 1.0
# lights🎶 1.0
# 83% 6.0
# interpretation 4.0
# https://t.co/lehxugmslc 1.0
# 😩😫💦💦❤😭 2.0
# happier🌻 1.0
# tsun 1.0
# https://t.co/26qku4i4b6 1.0
# playground 3.0
# https://t.co/whdlh5rrad 1.0
# hom… 3.0
# https://t.co/c98reoxf3f 1.0
# \nfor 2.0
# footie 2.0
# viacom 1.0
# menacing 1.0
# https://t.co/aaztcbt0oc 1.0
# https://t.co/de6qy003gj 1.0
# https://t.co/hxg2ptspo7 1.0
# https://t.co/4iugl2zuxn 1.0
# https://t.co/krulfqmppi 1.0
# uou 1.0
# https://t.co/nobotbym2a 2.0
# millionaire 4.0
# https://t.co/at9xyfuuwf 1.0
# lifeline 2.0
# assabet 1.0
# workplace 2.0
# semitic 2.0
# grooming 2.0
# decodable 1.0
# waaaayy 1.0
# https://t.co/g3fqd1gfoj 1.0
# photo' 1.0
# https://t.co/apfly5ym7s 1.0
# https://t.co/hp9golyueb 1.0
# reading) 1.0
# motive\ 1.0
# kinna 1.0
# https://t.co/gruvujo9br 1.0
# attit… 1.0
# 2-out-of-3 1.0
# https://t.co/zjfskttbxn 1.0
# cynica… 3.0
# west 79.0
# https://t.co/mwbwofasr5 1.0
# bb😘😘 1.0
# njayaka 1.0
# 💀😂😂😂😭😭😭 3.0
# motives 29.0
# geesh 2.0
# grandad 1.0
# photog 2.0
# much😂💀 1.0
# https://t.co/f3zbsgge7g 1.0
# https://t.co/q7pf73xkgz 1.0
# photos 138.0
# javier 2.0
# hashtag 27.0
# jeans—but 1.0
# https://t.co/wmxtxmhzqe 1.0
# https://t.co/m9t6xkmqjg 1.0
# 32 9.0
# https://t.co/h7cbkmqzej 1.0
# 2cent 1.0
# 😤🤦🏽‍♀️🤦🏽‍♀️🤦🏽‍♀️ 1.0
# https://t.co/v3b1zjdpob 1.0
# https://t.co/caglwd2hiw 8.0
# ivey 1.0
# pineda😘💕… 1.0
# https://t.co/33fptmuzxw 66.0
# https://t.co/e7amwrhnkp 1.0
# 🎵💙🐻😎 6.0
# https://t.co/6giahxua… 1.0
# technology 21.0
# easyq 6.0
# verified 5.0
# ❤️#happyb… 1.0
# https://t.co/qlh6ka57dd 1.0
# cesspool 1.0
# burrito/taco 1.0
# ottv 1.0
# verifies 1.0
# otto 17.0
# yessir 2.0
# daammnnn 1.0
# 🏃🏾🏃🏾🏃🏾 1.0
# https://t.co/sgtv9x46rn 1.0
# https://t.co/b0iq0d5ny8 1.0
# ig 66.0
# https://t.co/sazgcdxcqj 1.0
# hideaway 1.0
# mardigras 1.0
# https://t.co/r31gpvp9yj 1.0
# eline 1.0
# maxdd 1.0
# thejeffreymarsh 1.0
# tadka 2.0
# bein’ 1.0
# https://t.co/sdioxpcszk 1.0
# https://t.co/5r58pqifte 1.0
# pts 5.0
# https://t.co/8qjb8wiusi 9.0
# https://t.co/wzsxyh7zig 1.0
# by-product 1.0
# https://t.co/lt4au5ydrd 2.0
# 😔💓suicide 1.0
# bein… 6.0
# co/gv9yhvhupq 2.0
# https://t.co/awiqcghpfa 1.0
# https://t.co/ysnqevm7ma 2.0
# 💪🏻💯 1.0
# https://t.co/zheiepktgi 4.0
# “love 14.0
# https://t.co/kcjpvtbdht 1.0
# being 3975.0
# pencil/calculator 1.0
# sum1 3.0
# https://t.co/qv8gmvn6jy 1.0
# https://t.co/unu9ju34qu 1.0
# generator 16.0
# https://t.co/e9vcgijhwf 1.0
# fenna 2.0
# grounder 1.0
# https://t.co/xrzwypdrrk 1.0
# ghadeer 1.0
# https://t.co/pl8qaiguwg 5.0
# https://t.co/r5efprknvf 1.0
# komine_ 1.0
# kaveri 1.0
# https://t.co/6forznnzw1 1.0
# balloons… 1.0
# zion 2.0
# https://t.co/qunjovvopr 1.0
# decomposed 1.0
# sums 13.0
# s'much🤗 1.0
# sumo 1.0
# sumn 8.0
# summ 1.0
# traffic 58.0
# preference 8.0
# malfunctions 1.0
# naval 1.0
# https://t.co/wa6qatu2ck 1.0
# ascocentrum- 1.0
# whacking 1.0
# https://t.co/xxjswnzfu9 1.0
# superiority 1.0
# perfect😉 1.0
# obstruct 2.0
# burpees 1.0
# seating 2.0
# cam'ron 1.0
# rally's! 9.0
# mig… 1.0
# https://t.co/t1srqywpbq 1.0
# https://t.co/kkgkzx5xiw 1.0
# hardforks 1.0
# https://t.co/wpcwsqav81 1.0
# kidlet 1.0
# pervading 4.0
# partner'' 1.0
# ones😜 1.0
# yesss 10.0
# excelent 1.0
# https://t.co/jsthx32mkc 3.0
# https://t.co/j5rcv0xaet 1.0
# scottie 1.0
# low/high\ 1.0
# pigtails 2.0
# https://t.co/20iumbmb5z 1.0
# pentathlon 1.0
# https://t.co/lkjerksavj 3.0
# https://t.co/8esho8crko 1.0
# neonazis 1.0
# ryuseitai 1.0
# https://t.co/trrg7l0qqd 3.0
# https://t.co/evct0hkf7q 1.0
# 😍❤️i 1.0
# 🤕💀💀 1.0
# ganyan 1.0
# meniscus 1.0
# disparaging 1.0
# fareel 1.0
# –vera 2.0
# https://t.co/c0pvmfbumf 1.0
# youngji 14.0
# thailand 10.0
# goodbye🤦🏽‍♀️ 1.0
# vetter_vest 1.0
# co/wpbzz0fxz7 1.0
# hopkins 4.0
# n\n#siliconvalley 1.0
# https://t.co/bywze5saul 1.0
# https://t.co/bq17jbxju1 1.0
# https://t.co/l8eu203yog 1.0
# https://t.co/rwvfowrszo 1.0
# sensitively 1.0
# ass😏 1.0
# https://t.co/kqkuzxfztb 1.0
# disrupts 2.0
# https://t.co/244ptaho7m 1.0
# hunnyyy💗😜 1.0
# 🇺🇸… 9.0
# lively 4.0
# fizik 1.0
# ass😜 1.0
# pivot 3.0
# ass😑 1.0
# https://t.co/vrw1afajpa 1.0
# https://t.co/ajo77yipfy 1.0
# https://t.co/shqdxwmgfu 1.0
# 💕💕… 2.0
# bubbly 2.0
# ass😭 1.0
# https://t.co/ehnfqknyrv 1.0
# bitch😩😩😂 1.0
# light🎶 1.0
# https://t.co/r7mcqo9nwf 1.0
# 😍👓@bap_himchan 4.0
# https://t.co/6yfl0wtkeu 1.0
# sealed 1.0
# brazilian 40.0
# bubble 28.0
# witt 2.0
# https://t.co/8vvbl3ycau 1.0
# regardless💯 1.0
# whitepassing 1.0
# parent‼️😂 1.0
# https://t.co/9u1ts1ump9 2.0
# societal 1.0
# 640:415 1.0
# trip\ 1.0
# 23💙 1.0
# \r\r#aldubxdtbylandas 21.0
# witb 1.0
# https://t.co/pwxfxmcppj 1.0
# https://t.co/m4fmbwnkw9 1.0
# with 15644.0
# rebuilt 1.0
# is...don't 1.0
# https://t.co/ke2vb0qlgn 1.0
# abused 36.0
# monopoly 4.0
# self-seeking 4.0
# tripe 1.0
# https://t.co/rkjdu0yujn 1.0
# grayson's. 1.0
# dirty 138.0
# abuser 48.0
# abuses 2.0
# https://t.co/hhizdgh6it 1.0
# trips 12.0
# tripp 1.0
# https://t.co/mc83dlfv0i 1.0
# creaz 1.0
# more… 39.0
# allat 7.0
# https://t.co/eyo0xicq7h 1.0
# would… 5.0
# watches 11.0
# watcher 3.0
# horeeeeee 1.0
# i… 346.0
# associating 1.0
# 08:15 1.0
# follow-up 1.0
# watched 334.0
# after-work 1.0
# crean 5.0
# https://t.co/pvdi1zflym 1.0
# cream 81.0
# it❤loved 1.0
# yoga 24.0
# https://t.co/u493bosvgr 1.0
# fan💛🏀 1.0
# https://t.co/v3gdplbc1h 1.0
# yogi 4.0
# https://t.co/ylnznaikeb 3.0
# https://t.co/bszeu0e5ol 1.0
# quavos 1.0
# fix/help 1.0
# friggin 18.0
# youuuu❤❤ 1.0
# version,don't 1.0
# https://t.co/i7zwpe80xo 1.0
# itself🔋💙 1.0
# ┃┃╱╲ 12.0
# https://t.co/38iyllaema 1.0
# 06:13 1.0
# waving 4.0
# americ… 10.0
# https://t.co/huu57nmtxk 1.0
# https://t.co/hkn75vwped 1.0
# brotherhood 5.0
# rieva 1.0
# tricky 6.0
# natalie 10.0
# 👍☺💗 1.0
# natalia 2.0
# tricks 16.0
# ex-pm 1.0
# https://t.co/c2dd9r60qw 1.0
# https://t.co/pwpi9eqxgt 1.0
# perso… 1.0
# head-to-head 1.0
# https://t.co/yyk0annecp 1.0
# it💜 1.0
# it💝 1.0
# it💞 1.0
# caused 28.0
# beware 11.0
# it💓 1.0
# babe😘 2.0
# forecheck 3.0
# https://t.co/fwp8jepq1k 1.0
# it💁 1.0
# halsey 3.0
# babe😊 1.0
# causes 20.0
# \n\nalso 4.0
# nort 1.0
# https://t.co/rfdtmqazgv 1.0
# encourage 31.0
# https://t.co/molbdldyri 1.0
# riots 13.0
# hwhite 1.0
# nora 2.0
# excited—their 2.0
# https://t.co/waaovfoxb0 1.0
# it💯 5.0
# lcso 1.0
# countless 19.0
# https://t.co/u1owpqdskp 2.0
# norm 1.0
# 4-0 6.0
# 🛁🌹✨🖤 1.0
# https://t.co/wa7m8vmqet 2.0
# pple 1.0
# re-marketing 1.0
# floated 5.0
# baekhyun 15.0
# ppls 3.0
# https://t.co/idq0dfft… 1.0
# https://t.co/ncw3yyzjjq 1.0
# floater 1.0
# https://t.co/wact62vdxy 1.0
# https://t.co/80an2iadai 1.0
# https://t.co/wqrfgxmdaq 1.0
# re-did 1.0
# moines 3.0
# https://t.co/q55r1gjotq 1.0
# sans 2.0
# sumbody 1.0
# 4-7 2.0
# youfor 1.0
# https://t.co/cga2tugdbz 1.0
# sang 21.0
# sand 17.0
# sane 14.0
# bracho 1.0
# exclus… 1.0
# x1860 1.0
# ppl\ 1.0
# pkcrack 1.0
# https://t.co/mz6dgfoyru 1.0
# abbreviated 3.0
# https://t.co/khm0zfxfge 1.0
# 198 1.0
# 💓😚💘 1.0
# ❤️❤️❤️… 1.0
# joohyun 1.0
# 196 1.0
# 192 1.0
# 19- 1.0
# 19) 1.0
# 19% 4.0
# y'all😭❤️ 1.0
# 💞💗💘🎉 1.0
# birdwatching 1.0
# https://t.co/z0631vm3ar 2.0
# 👋🏻👋🏻😂 1.0
# https://t.co/hafajspabf 1.0
# 😅💖 2.0
# https://t.co/4ldz2knkfi 1.0
# https://t.co/evld5phzbr 2.0
# delek 1.0
# https://t.co/kzsngfgog7 1.0
# co/xj4wuabr7h 2.0
# trialing 1.0
# d'aaron 1.0
# https://t.co/z7hedxtqyc 1.0
# maryam 1.0
# kingangi 1.0
# hasn 1.0
# https://t.co/eevppzn24z 1.0
# hash 3.0
# https://t.co/joejamf8eo 1.0
# portrays 1.0
# ufc 5.0
# ganda 5.0
# https://t.co/baxpzj0eq6 1.0
# gande 1.0
# zirconia 1.0
# https://t.co/5qef1bp3ri 1.0
# dehumanizes 3.0
# 🤷🏼‍♂️😼 1.0
# periodic 3.0
# demlibs 1.0
# skepticism 3.0
# https://t.co/o6vapzy4eb 1.0
# heejun 1.0
# depart 5.0
# trumpsters 5.0
# reclaimed 1.0
# playfullness 1.0
# https://t.co/qveycpzils 1.0
# traumatized 2.0
# lanzini 3.0
# pliny 1.0
# "i've 2.0
# -amazing 2.0
# silva 1.0
# https://t.co/6exb4ief6s 1.0
# https://t.co/pkzjb484pj 1.0
# automata 1.0
# mori 1.0
# morn 3.0
# fragrance 14.0
# angry🔺 1.0
# https://t.co/oqfxxl7zqp 1.0
# mora 1.0
# morg 1.0
# more 4814.0
# jermey 1.0
# company 168.0
# corrected 14.0
# https://t.co/rahzxqmllv 1.0
# quick… 1.0
# https://t.co/nmohilxxfq 1.0
# wtf-i 1.0
# https://t.co/9t1dqulviu 2.0
# https://t.co/dkamu07arb 1.0
# heckeroni\ 1.0
# https://t.co/3d1wmrxpb8 1.0
# d-men 1.0
# https://t.co/bmc1gubhzy 1.0
# https://t.co/smrexvjqun 1.0
# https://t.co/wxjsiym9dl 1.0
# gringo 1.0
# https://t.co/n2bvc… 1.0
# -beggers 1.0
# https://t.co/mqrksjb41b 1.0
# learn 647.0
# knocked 13.0
# f***ing 1.0
# niela😭😭😘😘 1.0
# scramble 1.0
# https://t.co/ni9xwfzszu 1.0
# https://t.co/tiwcr91xqh 1.0
# https://t.co/fsmkgt3dhc 1.0
# https://t.co/izm2eqzrnb 1.0
# oddsmakers 1.0
# show/party 1.0
# https://t.co/zjxa7ysyze 1.0
# https://t.co/vaiuct7pfz 1.0
# bonded 1.0
# bogo 3.0
# hbcus 24.0
# huge 164.0
# juve 1.0
# johns… 1.0
# ministries 1.0
# https://t.co/bqecircbl2 1.0
# hugo 3.0
# hugh 15.0
# dismissed 2.0
# trump'll 1.0
# 🤤🤤🤤 3.0
# https://t.co/uwlkuzyba6 1.0
# !!!????? 1.0
# hugs 76.0
# dismisses 1.0
# https://t.co/wd03esmour 1.0
# https://t.co/pftupmer4s 1.0
# https://t.co/yhyljvnzl9 1.0
# 🐺🐕 1.0
# https://t.co/s1kztdryjq 1.0
# disgraced 1.0
# brett 7.0
# https://t.co/qzg6uq82zf 1.0
# https://t.co/txib1r7hoq 1.0
# correct\ 2.0
# resemble 2.0
# hilton/mccoy 1.0
# babe😍😘 2.0
# twisting 2.0
# https://t.co/w0ycqov9im 1.0
# https://t.co/0xj0sz8vum 1.0
# 02:30 1.0
# much💓💓 1.0
# eveyone 1.0
# https://t.co/pbkhewxp1l 1.0
# https://t.co/hnsz4iqvqa 1.0
# https://t.co/dkohnrkacr 1.0
# https://t.co/5bzzzc4gkf 1.0
# roshi 1.0
# byk 1.0
# installed 8.0
# paper 86.0
# scott 36.0
# installer 1.0
# https://t.co/queg7vain0 1.0
# cheerfulness 1.0
# saucy 4.0
# wabukala 1.0
# ethnocentric 1.0
# bangle 1.0
# ;d 7.0
# https://t.co/0kxd7cfkqg 3.0
# bypass 2.0
# nervousing 1.0
# sauce 33.0
# mindclone 1.0
# https://t.co/5pv9hiq0vt 1.0
# colleague 15.0
# susana 1.0
# https://t.co/l20dqnrfay 1.0
# endpapers 1.0
# for❤️ 1.0
# villarreal 1.0
# https://t.co/ut9ncsyxk6 1.0
# https://t.co/xmxc0sib8f 1.0
# https://t.co/er7thdqdvl 1.0
# https://t.co/mn62voyjtm 1.0
# https://t.co/5uiaike9ha 1.0
# idols 16.0
# emojis) 1.0
# 77777% 1.0
# course\ 1.0
# melinadoodle 1.0
# https://t.co/qqff7uwvre 1.0
# everytime 72.0
# https://t.co/j1zagonk3t 1.0
# co/pvpkcwix3r 1.0
# courses 1.0
# lmao😂❤ 1.0
# https://t.co/j7avp… 1.0
# kimxi 1.0
# shocking 11.0
# /chuckles 1.0
# kfc 7.0
# begged 7.0
# https://t.co/dh6qgieu5g 1.0
# school❤ 2.0
# https://t.co/piijpdlun2 1.0
# homegirls 1.0
# 🤔😂😂😂 1.0
# https://t.co/hkmebg5ilz 1.0
# arashi 1.0
# zaynnnn 1.0
# caeser 1.0
# gunpla 1.0
# https://t.co/ilezqu8itq 1.0
# lipstick 17.0
# ernie 1.0
# /usr 1.0
# scoops 1.0
# relaxers 1.0
# 00:35 1.0
# research 43.0
# $pwrd 1.0
# looot 1.0
# life-changing 2.0
# offline 8.0
# 💪🏾💙🙏🏽🙌🏽😘 1.0
# https://t.co/kp2dp7dgos 3.0
# https://t.co/f6xciqvxwn 1.0
# bou-atful 2.0
# co/6wtwjkwixv 1.0
# https://t.co/mr1llxs4ep 1.0
# ecologically 1.0
# gangshit 1.0
# yoshi-p 1.0
# mcchicken 1.0
# *looking 3.0
# https://t.co/oc1db1ppti 1.0
# hospedarse 2.0
# quernemoen 2.0
# quickwest 2.0
# https://t.co/cnnjbgaswg 1.0
# https://t.co/aeio54dxtn 1.0
# https://t.co/ywnk6tnznk 1.0
# movie💯#getout 1.0
# https://t.co/t7ka3fuiqt 1.0
# 12.32 2.0
# https://t.co/jvkubvr5pf 1.0
# president’s 5.0
# them… 19.0
# https://t.co/hmoxl3bbfv 1.0
# post-sc2 1.0
# //but 1.0
# multi-billion 1.0
# https://t.co/c2nktfwkas 1.0
# ringside 1.0
# swipe 3.0
# our… 28.0
# nomo 9.0
# kahit 4.0
# noms 1.0
# ilysfm 1.0
# saint 31.0
# olde 1.0
# essays 11.0
# https://t.co/bf494eundu 3.0
# 5.99 1.0
# https://t.co/bliuiqp0eh 1.0
# 5.90 2.0
# https://t.co/bvqrixqiar 1.0
# stifle 1.0
# essay) 1.0
# watching/recording 1.0
# syringes 1.0
# him😍😍#happybirthdayjustinbieber 1.0
# 😫😌💓 1.0
# https://t.co/sv59gaozaa 1.0
# https://t.co/gy4hirh2y3 1.0
# getaway 2.0
# https://t.co/vhumylxmrr 1.0
# dismantling 5.0
# https://t.co/pnxkmaruzm 1.0
# 🙏🏾❤ 1.0
# https://t.co/2ncxzwnyzq 1.0
# https://t.co/juillz8dqv 2.0
# *bwut 1.0
# https://t.co/2hrxghhjyt 1.0
# 😍🇵🇷 1.0
# beltre 1.0
# https://t.co/bbtfiwzk3r 1.0
# *trips 2.0
# guarding 2.0
# ding-pecker 1.0
# blond 4.0
# https://t.co/k2gnbdhfzq 1.0
# fermented 1.0
# mf'n 2.0
# permanence 1.0
# miah 1.0
# ut😍\ 1.0
# recognizing 8.0
# 🎉😄 1.0
# 🎉😍 3.0
# 🎉😊 1.0
# pringles 3.0
# bg=b000ff00 1.0
# singles 9.0
# https://t.co/5gmodp1cvg 1.0
# singlet 1.0
# !!!!!!!!!!!! 1.0
# shake-up 1.0
# co/kbhafojzz4 1.0
# https://t.co/lpd5kzbfxn 1.0
# laeng 1.0
# more⁶𓅓 1.0
# https://t.co/jmp5ldzrf7 1.0
# understands 38.0
# https://t.co/etgiz3dq4o 1.0
# https://t.co/cohrd3agu3 1.0
# incase 38.0
# bad/missed 1.0
# someones 9.0
# wording 4.0
# https://t.co/gnyzlgtzff 1.0
# dudes\neconomy 5.0
# exterminate 2.0
# blended 2.0
# accommodations 2.0
# https://t.co/eihm9bpxzl 1.0
# https://t.co/fyx0wcvnm7 1.0
# 💜📸 1.0
# https://t.co/ds98feff4o 1.0
# naomi 1.0
# *did* 2.0
# overwhelmed 60.0
# blender 3.0
# https://t.co/onkxbr86h5 1.0
# -anonymous 2.0
# https://t.co/xnl7g4yqjr 2.0
# gooey 3.0
# terr… 1.0
# webscale 1.0
# https://t.co/f90td8vxo2 1.0
# indifference 2.0
# columns 4.0
# https://t.co/ykhsnglakd 2.0
# https://t.co/gg1gnwxhqm 1.0
# damnin 1.0
# 3m 1.0
# pleasure\ 1.0
# secular 5.0
# https://t.co/6vul0vez6r 1.0
# remedy 37.0
# got7✨bts 1.0
# https://t.co/ajdhg8dngy 1.0
# compass 4.0
# damnit 8.0
# distraction 13.0
# https://t.co/xnemajspxv 1.0
# yujwon 1.0
# pleasures 3.0
# https://t.co/u9fmp1dcqh 1.0
# https://t.co/cvaawyre2s 1.0
# rythem 1.0
# \n#therealoneals 2.0
# https://t.co/gq3uj8ffe9 4.0
# insane 36.0
# troyes 1.0
# \n\nempress 1.0
# bozo 4.0
# self-loathing 2.0
# activists 7.0
# 316 1.0
# whateverrrr 1.0
# collectively 4.0
# https://t.co/5byoup0yyn 1.0
# ✌🏽❤ 1.0
# https://t.co/dw7vjffheb 14.0
# https://t.co/yci7uifnem 1.0
# 31% 7.0
# i've, 1.0
# i've. 1.0
# https://t.co/qicxv1w9ox 1.0
# forums 1.0
# deactivate 1.0
# https://t.co/b5ershmppq 5.0
# https://t.co/mzaw8zsin3 1.0
# puspa 1.0
# momusu 1.0
# nitpick 6.0
# thrive 14.0
# unity\ 1.0
# mitsuko 1.0
# https://t.co/sti8plvsaw 2.0
# 😘💛💛💛 1.0
# zombie-cunt 1.0
# condones 1.0
# 31k 1.0
# w/dis 2.0
# https://t.co/5px867hfw4 1.0
# hellywood 1.0
# shampoos 1.0
# https://t.co/7rrja4xbdn 1.0
# empowering 8.0
# franny 1.0
# sheldon 2.0
# https://t.co/9reeymwqck 1.0
# 😘🎂🎉🎊 1.0
# https://t.co/xwbw0vcecx 1.0
# https://t.co/5pxi02vdm5 1.0
# retarded 10.0
# 😪😂 1.0
# beli 2.0
# bell 56.0
# one-two' 1.0
# thoooo 1.0
# 😪😓 1.0
# bro💎 1.0
# co/penjicohbw 3.0
# eva 9.0
# https://t.co/7ys0e6yfsd 1.0
# https://t.co/wlhkab0fiw 1.0
# belt 16.0
# 9:34 1.0
# warfield 1.0
# passion😤😤😤😤 1.0
# 😭😓 1.0
# 😪😪 2.0
# https://t.co/u5iw6elln0 1.0
# messed… 1.0
# https://t.co/2ec2j9wyki 1.0
# suburbs 3.0
# initiation 1.0
# acqdemy 1.0
# *for* 1.0
# dude🤑💘 1.0
# https://t.co/5i8r5ehsg5 1.0
# https://t.co/yixbtdcywd 1.0
# 💕❤️ 5.0
# nro 1.0
# top-down 1.0
# banjo-kazooie 1.0
# stardoll 2.0
# nrg 1.0
# blizz 1.0
# fast.she 1.0
# complements 5.0
# bae💜💖 1.0
# awake 32.0
# https://t.co/pypmrm3jvc 1.0
# pacemaker 1.0
# 💖💐 1.0
# https://t.co/8hndq6qjed 1.0
# presses 2.0
# https://t.co/uvwv5jcdw7 1.0
# investigate😂😂 1.0
# osheaga 1.0
# budget 62.0
# https://t.co/w8pyo59o5o 1.0
# https://t.co/mzmipaarjw 1.0
# pressed 15.0
# child🙄 1.0
# https://t.co/u3t4qeywkt 1.0
# https://t.co/34imkc00cs 1.0
# lib… 1.0
# it😍😍😍 1.0
# disca… 1.0
# agitation 2.0
# lynette 1.0
# averaging 2.0
# yourgdreams 1.0
# binding 1.0
# 🍳🥓🥞 1.0
# manfried 1.0
# 34 7.0
# behemoth\ 1.0
# 😒nobody 1.0
# raiders 5.0
# starlight 3.0
# 📽with🇯🇵sub 1.0
# 2\n\ni 1.0
# non-college 1.0
# much😭😭💜💜 1.0
# ‼️🤷🏽‍♀️ 1.0
# https://t.co/ywxrx7df0d 1.0
# https://t.co/bozzjbtw2z 1.0
# 😭👀 1.0
# https://t.co/54mgmuc5as 1.0
# diddleys 1.0
# bounc… 1.0
# https://t.co/9ahefleyhf 1.0
# ainters 1.0
# *cries 2.0
# matheny 1.0
# nickname 7.0
# nabs 2.0
# shitposters 1.0
# kno 56.0
# knk 2.0
# https://t.co/okzdzfe6kk 1.0
# kng 1.0
# https://t.co/acaawo8cvm 1.0
# https://t.co/udvh9wncxs 1.0
# https://t.co/st5celdikr 1.0
# co/frwnc8vi8t 1.0
# fuckwit 1.0
# salerio 1.0
# 🔺👈🏽 1.0
# knw 5.0
# obamacare’s 1.0
# sanibel 1.0
# https://t.co/4mkmutiwju 1.0
# clasped 2.0
# lads 12.0
# https://t.co/3gwdjojits 1.0
# risks\ 1.0
# \nthat 4.0
# salve 1.0
# hercules 3.0
# ❤❤🎉🎊 1.0
# https://t.co/azbvapiswc 1.0
# 😛😍😍😍😍😍😍😍😍 1.0
# abstention 1.0
# pun-able 1.0
# waste/… 1.0
# newsssss 1.0
# https://t.co/gstye5pykt 1.0
# parents 535.0
# 🙈😅 1.0
# https://t.co/eq7u201dmv 1.0
# 🙈😌 5.0
# https://t.co/fbnrvrvjsg 1.0
# https://t.co/tn51dwctgf 1.0
# 🤘🏾🤘🏾 1.0
# bro❣️😊 1.0
# couple 288.0
# https://t.co/lcfzsm9qhf 1.0
# https://t.co/avks3v3rld 1.0
# madee🤤❤️ 1.0
# davy-2017 1.0
# https://t.co/8if3sx6jwp 1.0
# https://t.co/cewhfszwef 1.0
# https://t.co/ufslbq3rqi 2.0
# https://t.co/vqsplo885s 1.0
# counterintuitive 1.0
# https://t.co/tgaw9c24rx 4.0
# https://t.co/k0cunwj0mr 1.0
# https://t.co/0uchbi76pa 1.0
# chorus 35.0
# iphone6 1.0
# sl's. 1.0
# 💛🖤 2.0
# twitter.com/googuns_lulz/status/836789091379326976 1.0
# https://t.co/ivc4siqxhd 1.0
# https://t.co/9u7tcdi0lo 1.0
# sorbet 1.0
# bounce 26.0
# -sorry 1.0
# bouncy 1.0
# greener 2.0
# sh*t\ 1.0
# https://t.co/6srjbyrxru 1.0
# and/or 16.0
# shitloads 1.0
# https://t.co/rlgfrkseum 2.0
# novelty 1.0
# unstbl 1.0
# behave 10.0
# awwie 1.0
# country… 6.0
# 💯not 1.0
# https://t.co/bpjgfr5cax 3.0
# https://t.co/yv6ncl4ya5 1.0
# taako 2.0
# https://t.co/4o9z3fmfoh 1.0
# https://t.co/tvn0hrwydq 1.0
# girl😭😭😭its 1.0
# gift...it 1.0
# https://t.co/zhrfdjztft 1.0
# https://t.co/caz4zgekq6 1.0
# 190,991 1.0
# nauseated 1.0
# https://t.co/wrrt8wzpfu 1.0
# https://t.co/2zlw7vinip 1.0
# ^is 1.0
# yeahhhhhh 1.0
# co/qv6mckam4u 1.0
# https://t.co/pkmf5qagiu 1.0
# https://t.co/4gf5xtjm3l 1.0
# scraggly 1.0
# agave 1.0
# https://t.co/skwfsz2isp 1.0
# colourism 1.0
# mouth 175.0
# 1gb 1.0
# country” 1.0
# buntut 1.0
# https://t.co/zl4z2p7aep 1.0
# terrorists 48.0
# -gives 2.0
# intl 1.0
# into 1547.0
# ✊🏼❤️ 2.0
# intj 1.0
# milk™ 1.0
# katia 1.0
# inty 1.0
# too💕💕 2.0
# atheist\ 1.0
# inspects 1.0
# xen… 1.0
# tasting 13.0
# these💕 1.0
# flyers....couldn't 1.0
# these💓 1.0
# bios 3.0
# sub-class 1.0
# https://t.co/cxxkbu7j29 4.0
# https://t.co/cbggrziojk 1.0
# https://t.co/07zcv2jzh5 2.0
# hawaiian 4.0
# https://t.co/d9xtwlmugw 1.0
# brief-amgen 1.0
# https://t.co/yw59s7k6fy 1.0
# https://t.co/ra8whyjj7c 1.0
# \__/ 1.0
# believe😂😂 1.0
# atlantic 86.0
# gwaal 1.0
# 👇🏻 3.0
# erick 2.0
# https://t.co/pph4yx6diq 1.0
# suffer😕 1.0
# erica 6.0
# paired 3.0
# https://t.co/pkippeyph8 2.0
# one😅😂 1.0
# 5...let 1.0
# https://t.co/4lewjivrdn 1.0
# https://t.co/uf60ycwa12 1.0
# 😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍😍💍 5.0
# haunt 10.0
# duration 1.0
# https://t.co/dyjubnhptj 1.0
# https://t.co/nzgwayam6j 1.0
# https://t.co/1vjtkmbuq0 1.0
# amandas 1.0
# https://t.co/cda4ooslsv 1.0
# pewds 1.0
# https://t.co/etnvymezvb 1.0
# puzzling 1.0
# https://t.co/5ybxbtxlip 1.0
# clapback 1.0
# https://t.co/prpc4eepbz 1.0
# pewdz 1.0
# hypernormalisation 1.0
# https://t.co/w5fopx0miw 1.0
# co/hrwufd2mzu 1.0
# revision 1.0
# kylighter 1.0
# capitalizing 2.0
# 😍😘😙😚💋 1.0
# rexha 4.0
# https://t.co/kbnb0w0gjm 1.0
# doggys 1.0
# bianca 1.0
# suppression 4.0
# https://t.co/ao6c6ma2fm 1.0
# r7-6 1.0
# 😍🍆💦💋 1.0
# https://t.co/mlugrdtzke 1.0
# sports\ 1.0
# danielle\ 1.0
# phat❤❤ 1.0
# algorithm 3.0
# friend😍🙇good 1.0
# maradona 1.0
# https://t.co/3yifhzqmln 3.0
# advertisment 1.0
# crease 1.0
# ❤️💋#rhobh 1.0
# senioritis 10.0
# noooooooo 2.0
# tattooing 1.0
# northside 1.0
# https://t.co/elaqsy7ssr 1.0
# rayo… 1.0
# russia'… 1.0
# https://t.co/oxtfyhvrqf 1.0
# levelland 1.0
# borfday 1.0
# https://t.co/htqb0ffgok 1.0
# https://t.co/spfyvhk2lf 1.0
# 507 1.0
# https://t.co/lnzs3rwlgl 1.0
# 💜💜🎉 2.0
# detectives 1.0
# unforseen 1.0
# turkish 2.0
# amo💗😊🙈 1.0
# bzzbussin 1.0
# horsing 1.0
# https://t.co/fdjeuaco4y 1.0
# https://t.co/kltlwseyag 1.0
# https://t.co/9mougobguh 1.0
# carelessly 1.0
# w/you 3.0
# 10/1… 23.0
# 다음주 1.0
# plastic… 1.0
# https://t.co/etwrq081np 1.0
# 15:20 1.0
# https://t.co/0qnsgzlwhi 1.0
# well-done 6.0
# miahaha 1.0
# 👯💃 2.0
# yelle… 1.0
# decorating 2.0
# minerals 1.0
# padded 1.0
# https://t.co/fgydsgkzxh 1.0
# f 56.0
# https://t.co/dehppxjqbq 1.0
# pre-existing 9.0
# disheveled 1.0
# yooooo😂🎥🔥 1.0
# 👏🏼👍🏼 1.0
# kogyeol 1.0
# sequence\ 1.0
# you😘😊 1.0
# victon 1.0
# https://t.co/6lpakwnq52 1.0
# https://t.co/yb4mdtwoiv 1.0
# alie 1.0
# you😘😚 1.0
# you😘😘 1.0
# https://t.co/ogtjj7102h 1.0
# video 958.0
# wi… 144.0
# haiku 6.0
# https://t.co/2d… 1.0
# dynamics 1.0
# dicked 2.0
# victor 25.0
# alix 1.0
# https://t.co/zorbx0j4sg 2.0
# apology… 1.0
# flannel 3.0
# sweaty 8.0
# https://t.co/bbc0hwvuvl 1.0
# 💞☝ 1.0
# https://t.co/barnt5omtw 1.0
# flowing 24.0
# 💘grethan 4.0
# https://t.co/xj4wqpi4ya 1.0
# harassing 5.0
# https://t.co/sh6mbtdphv 3.0
# admn 1.0
# https://t.co/qdwwnurxx5 1.0
# https://t.co/ng4jttv8qr 2.0
# alt-right 12.0
# wishy-washy 1.0
# dolly 1.0
# 🙎🏽 2.0
# ryszard 1.0
# https://t.co/f5ms8sagfj 1.0
# lmfaoooooooooooooo 1.0
# krist 1.0
# squirming 1.0
# fifteen 3.0
# musset 1.0
# alis 7.0
# 😭❤❤ 2.0
# https://t.co/maityjfxvv 1.0
# https://t.co/mmrd2izx7t 1.0
# information-technology 1.0
# https://t.co/rcecueikvz 1.0
# https://t.co/ehacpprx0y 1.0
# https://t.co/vnu9ahst1x 1.0
# derby 1.0
# memeeee 1.0
# realise🎶 1.0
# happpyyy 1.0
# makes 1522.0
# maker 18.0
# toots😘 1.0
# https://t.co/pkceln3ice 1.0
# panicked 1.0
# riva 1.0
# democrats—to 1.0
# pf- 1.0
# https://t.co/6ln0fezo74 1.0
# yeaaaa 1.0
# https://t.co/hlin6o28bk 2.0
# desiring 1.0
# confidence 46.0
# 🤘🏼🤘🏼 2.0
# out🙄😩 1.0
# nagoya 1.0
# https://t.co/aqpg7dehrx 1.0
# 😂😂😭😭 1.0
# immigrants\ 3.0
# 👑👑👑 2.0
# https://t.co/2jgnliu0ro 1.0
# blondies 1.0
# dayyy~ 6.0
# milkovich… 1.0
# actuall 1.0
# dayyyy 2.0
# approps 1.0
# https://t.co/amxmrt5xwj 1.0
# losin 2.0
# actualy 1.0
# antichrist 1.0
# https://t.co/fvpdibztii 1.0
# customer 89.0
# https://t.co/1rrtgdtf3u 2.0
# integrating 1.0
# https://t.co/c97kelbywx 1.0
# rochesterians 1.0
# retell 1.0
# https://t.co/jogrwnwqpt 1.0
# choi 7.0
# gay😆 1.0
# scatter 1.0
# https://t.co/hqece7bfzg 1.0
# boyyyyy 2.0
# https://t.co/1p0l4wious 1.0
# https://t.co/e6lmotx3eo 1.0
# https://t.co/cngsc5met8 1.0
# https://t.co/9ljrwwyuyq 1.0
# https://t.co/mjaanvxsma 1.0
# rods 2.0
# https://t.co/htm98fm1jc 1.0
# https://t.co/eterompg8i 1.0
# https://t.co/8atxkwa6kr 1.0
# ^cr 8.0
# $aapl 1.0
# ?!... 2.0
# cross-eyed 1.0
# comedy 35.0
# intelligent 25.0
# clasping 1.0
# maaaaybe 1.0
# https://t.co/jdmlascevn 1.0
# this😩😛😂 1.0
# https://t.co/aqwgplslto 1.0
# chow 2.0
# https://t.co/czie8o2xkl 1.0
# 🤦🏾‍♀️💯 1.0
# choy 1.0
# noche\ 1.0
# daesung 2.0
# https://t.co/s7nxtpvg… 1.0
# mjb 1.0
# https://t.co/blehvlvgbr 1.0
# ღ~ 1.0
# https://t.co/pptrwx0kjy 1.0
# sux 3.0
# k-kiss 1.0
# 🤦🏾‍♀️💉 1.0
# noches 2.0
# https://t.co/h5jhufptk8 1.0
# 5'7" 1.0
# houston 40.0
# evolutionary 1.0
# thigh 30.0
# co/51trz2tb74 1.0
# https://t.co/wqvkxndwfo 1.0
# insight 20.0
# https://t.co/wcobwgji5q 1.0
# lamo 1.0
# yglesias 1.0
# https://t.co/jisszffxye 1.0
# bigdaddycelik 1.0
# mrket 7.0
# https://t.co/wetpvtnief 1.0
# smoove 2.0
# d'ache 1.0
# https://t.co/exrqclkkl6 1.0
# jetsons 1.0
# sinigang😍but 1.0
# https://t.co/cvx2fkbfdp 1.0
# equalise 1.0
# wawa 3.0
# \nboy 8.0
# 😘💋🙌🏼💋 1.0
# https://t.co/tminnfoxfn 2.0
# derivative 1.0
# sabotaging 1.0
# physicians 1.0
# prosper 18.0
# https://t.co/zvsi5c3gqd 1.0
# https://t.co/73mmarnpgp 1.0
# junior-high 1.0
# snake 23.0
# maslow 1.0
# https://t.co/pnvznjacc0 1.0
# luiski 1.0
# https://t.co/uonhuvgg9c 1.0
# https://t.co/yhnpr0unv5 1.0
# 1:51 2.0
# ecstacy 1.0
# https://t.co/i9c9vzgnys 1.0
# off-script 1.0
# https://t.co/cnboqxvw8n 1.0
# mamasita 1.0
# twitter.com/favstar_bot/status/836761578577920000 1.0
# https://t.co/zdxhmjat6i 1.0
# cheesecakes 1.0
# denzel 3.0
# sweethurt 1.0
# shortage 2.0
# https://t.co/yg90e8k1po 1.0
# https://t.co/oqcshhbe51 1.0
# calipari 2.0
# verily 4.0
# pretzel 2.0
# alejandro 2.0
# books 150.0
# gordon/andresonbetter 1.0
# 4all… 14.0
# witness 17.0
# alejandra 1.0
# must-read 2.0
# ' 1655.0
# https://t.co/pqum9retem 3.0
# subhumans 1.0
# https://t.co/mhtgb5dyao 1.0
# re… 87.0
# regulation… 3.0
# https://t.co/lell5ogwka 1.0
# 🇺🇸compassionate 1.0
# https://t.co/pd0sdoounb 1.0
# book\ 3.0
# https://t.co/rqzztlm2uk 1.0
# https://t.co/oencb6j7mn 1.0
# you!!'😃🎾 1.0
# https://t.co/1zmp9hklql 1.0
# critiquing 3.0
# out… 23.0
# cheong 1.0
# book- 1.0
# greedy 9.0
# kuhr 1.0
# npcs 2.0
# https://t.co/9ni20ogcm5 1.0
# https://t.co/fpilbvew4j 1.0
# protect… 2.0
# out‼ 1.0
# memeories 2.0
# 😍😘💁🏼 6.0
# 🌹💟 1.0
# wawo 1.0
# 🌹💙 1.0
# 🌹💘 1.0
# 🌹💖 1.0
# could 1852.0
# https://t.co/jzhq1bkiee 1.0
# waү 1.0
# 😆❤️🎤👍 1.0
# congratul… 1.0
# bette… 1.0
# receding 5.0
# out” 2.0
# 500.0 2.0
# https://t.co/hztaplylzv 1.0
# realoy 1.0
# viralhog 1.0
# vickers 1.0
# https://t.co/vqneeqknxh 1.0
# minding 5.0
# river-tumbled 1.0
# klan 7.0
# leica 1.0
# https://t.co/49owzo3yzs 1.0
# solu… 4.0
# https://t.co/ntmhi4qvxg 1.0
# co/lm55yytlwa 1.0
# cohan 1.0
# 🔮💜// 1.0
# heirloom 1.0
# articles\ 1.0
# 😊😁☺️i 1.0
# lumen 1.0
# feed… 1.0
# bea… 3.0
# https://t.co/jii7fnwdwv 1.0
# interests 43.0
# enforcement 27.0
# https://t.co/kxbvypcwcu 1.0
# stomach 77.0
# ohhhhhhh 6.0
# 😎🌤 1.0
# https://t.co/kleinanaur 1.0
# were'not 1.0
# interest~ 10.0
# https://t.co/lfq1mw2zu3 1.0
# gay\ 4.0
# https://t.co/vrd4ifl973 1.0
# 😎🌼 1.0
# https://t.co/vg3ssdhjoy 1.0
# 😎🌃 1.0
# https://t.co/qnyyqp2dyy 2.0
# https://t.co/ekwsgroqnj 2.0
# gaya 1.0
# interest\ 5.0
# 🥔❤️ 1.0
# gays 25.0
# kroft 1.0
# false 137.0
# shrinks 2.0
# erika 12.0
# tonighh 1.0
# https://t.co/djmwchiitc 1.0
# tonight 1351.0
# ya💙💙💕💕 1.0
# homes/incarcerating 1.0
# yoonjin 20.0
# https://t.co/k1bgzanwcf 2.0
# https://t.co/y… 1.0
# kms🤔 1.0
# https://t.co/iyi1hbyjer 1.0
# 👰🏻💙 1.0
# https://t.co/fguujdmqk3 1.0
# https://t.co/3jzyh24oca 1.0
# day❤❤❤ 1.0
# optics\ 1.0
# machinima 1.0
# https://t.co/bhbspn27kk 1.0
# https://t.co/ex5lqfpetx 2.0
# ily💖💖💖 1.0
# manor 2.0
# finsh 1.0
# sodapop 1.0
# krogers 1.0
# combination😌⛈ 1.0
# 🐽𵠽򓐽𷠽򖀠always 1.0
# regressing 1.0
# 💋🎉 1.0
# https://t.co/t2xmts3bmg 2.0
# bren 1.0
# placement 13.0
# breh 1.0
# bref 1.0
# bree 4.0
# bred 1.0
# 😂😭🕷 1.0
# https://t.co/sp7txnfd3s 1.0
# https://t.co/0bkjrnd44q 1.0
# undersea 2.0
# brew 6.0
# brev 1.0
# bret 1.0
# scotty 4.0
# 36-31 1.0
# https://t.co/yawal3ap6x 1.0
# but...i'll 1.0
# babbbb💖 1.0
# abotu 1.0
# taps 3.0
# cutes… 1.0
# https://t.co/qeqxutxzmg 1.0
# entities 1.0
# tape 25.0
# sjkei 1.0
# tapi 5.0
# riding 34.0
# https://t.co/4frm3ad8tq 1.0
# abba 4.0
# wknfks 1.0
# abbi 1.0
# matter… 5.0
# molasses 1.0
# abbs 1.0
# https://t.co/5g4kdelgyj 1.0
# ipvanish 1.0
# sinus 3.0
# wring 1.0
# abby 18.0
# dominican 11.0
# aer 1.0
# 5/5 2.0
# sunbae 1.0
# https://t.co/gqbwgis8rr 2.0
# taxes 266.0
# https://t.co/myxjvvlu4u 1.0
# kereta 2.0
# stuff 465.0
# https://t.co/kyogkwlaok 1.0
# coming… 7.0
# thakeray 1.0
# ohio 34.0
# usvi 1.0
# 🤔😡#idliketoknow 1.0
# guessing 19.0
# https://t.co/h89dddwzph 1.0
# pronoun 2.0
# https://t.co/nqyi9cj6os 1.0
# frame 23.0
# \n\ncustom 1.0
# https://t.co/xrxvzz29mi 1.0
# https://t.co/x7mb3vqohq 1.0
# fact-only 1.0
# https://t.co/pbatjuzklo 1.0
# https://t.co/hutm5yacc4 1.0
# alessandra 2.0
# does… 6.0
# lattimore 1.0
# dungeon 2.0
# https://t.co/21ccjyagft 1.0
# destiny 43.0
# nuclear 10.0
# so😬😬😬 7.0
# https://t.co/xqfijpbrhn 1.0
# loooord 1.0
# ‘i’m 1.0
# repetitively 1.0
# thght 1.0
# one-hand 1.0
# https://t.co/jebsgkgs7b 1.0
# wish😊love 1.0
# 🙄🙄🙄😂😂 1.0
# https://t.co/fms3itue54 2.0
# staring 20.0
# marty 3.0
# https://t.co/jcmunlbgef 3.0
# suanne 1.0
# once\ 2.0
# challengers 1.0
# avengers\ 1.0
# —https… 1.0
# secret】 1.0
# diverting\ 1.0
# word… 1.0
# https://t.co/h5pquicplz 1.0
# marta 1.0
# .?! 1.0
# https://t.co/dh4qgpxglh 1.0
# brother😂😂 1.0
# movei 1.0
# https://t.co/ueadtozjyn 1.0
# https://t.co/kvihnt5z… 1.0
# isl… 2.0
# https://t.co/zjcqxlmrvl 1.0
# indict 1.0
# worldstar 1.0
# 😭❤️😍 1.0
# mailman 1.0
# like… 44.0
# rb4 1.0
# 🙇🏾☺ 1.0
# 😭😭😭😭😂😩🙄i 1.0
# genetic 1.0
# https://t.co/a6bsm7chw2 6.0
# millieh8sdms 6.0
# https://t.co/b8qk7dqfyt 2.0
# feather 1.0
# podcast\ 1.0
# infastructure 1.0
# profitly 1.0
# like🙎 1.0
# https://t.co/wnudsboh3d 1.0
# scallywag 1.0
# https://t.co/9vr0t4ewg0 1.0
# ambien-induced 1.0
# hateful 116.0
# https://t.co/gw51vjsskj 1.0
# asia… 1.0
# banish 11.0
# cvx 1.0
# cvv 1.0
# https://t.co/o3mmsn2zfo 1.0
# https://t.co/xvsw9znk0e 1.0
# cvs 1.0
# podcasts 5.0
# rbi 4.0
# hahaha 164.0
# 👊🏾👊🏾 1.0
# rbf 2.0
# https://t.co/ny1psnhyvy 1.0
# sunmin🌹 1.0
# https://t.co/9xppkiu9od 1.0
# intuit… 1.0
# screensaver❤️❤️@ethandolan 1.0
# differen… 1.0
# uggg 1.0
# veey 1.0
# said\n 35.0
# thundertits 1.0
# tattoo 50.0
# peo… 57.0
# breakfast🍻🥗🍉 1.0
# ishrat 1.0
# psyqo 1.0
# gibbo 1.0
# nerd 17.0
# https://t.co/yzf6d213wi 3.0
# https://t.co/vmfru8rnpe 1.0
# https://t.co/ls2aihnfvd 1.0
# https://t.co/oegrfh4tbg 1.0
# https://t.co/kqrzfq… 1.0
# pickin 1.0
# nerf 2.0
# angel,you're 1.0
# 3-2-1 1.0
# 😩❤️👅 1.0
# den… 1.0
# shaking… 1.0
# https://t.co/pu85czmvy2 1.0
# https://t.co/h621d7kyeq 1.0
# diplomatically 1.0
# censoring 1.0
# https://t.co/o6szolwelf 1.0
# mythologise 1.0
# thks 1.0
# text/snapchat 1.0
# ❤️🍻🎊🎉 1.0
# allattttt 10.0
# of\ 2.0
# diabetes 3.0
# ofc 13.0
# ofa 1.0
# off 1396.0
# joyceleebrook 1.0
# phat 7.0
# ofn 2.0
# https://t.co/iy1zylhwod 1.0
# dissing 7.0
# phan 1.0
# pham 1.0
# oft 2.0
# of~ 1.0
# type-c 1.0
# rielly 1.0
# wonderng 1.0
# https://t.co/7sspnwdupe 1.0
# newest 116.0
# https://t.co/ofopjdkh7r 1.0
# 11/10 5.0
# https://t.co/wh0kyeaja8 1.0
# saturday😍😭 1.0
# productively 1.0
# kisses😂😂 1.0
# https://t.co/kn3ifz9hio 1.0
# afford.that 1.0
# 👀🤘🏽 1.0
# 🇯🇵 2.0
# neoliberal 1.0
# \n#احمد_الحسن 1.0
# 🇯🇲 1.0
# crack 48.0
# https://t.co/db92gn9jrk 1.0
# odd/off 1.0
# bartending 1.0
# https://t.co/afpgceiw8s 1.0
# cruz 13.0
# zimbabwe 1.0
# dish 17.0
# ranbu 1.0
# 😪#thestruggleisreal 1.0
# bulge 2.0
# schmitt 1.0
# https://t.co/osrgdcbmky 1.0
# gurumehar 7.0
# https://t.co/go7ok1ybum 1.0
# https://t.co/zr8ksuu7hh 1.0
# become 712.0
# sprain 2.0
# 💀💀💀💀💀😭 1.0
# https://t.co/xnc6fl0va3 1.0
# https://t.co/sejxxy3vaq 1.0
# https://t.co/kkxsi7fidc 1.0
# cap… 1.0
# https://t.co/uap2ggebwj 1.0
# opp… 1.0
# https://t.co/wagjgssduu 1.0
# gymnastics 2.0
# https://t.co/jafd2borxq 2.0
# hissing 1.0
# tanshi 1.0
# recognition 50.0
# 13/10 2.0
# hipsters 2.0
# punditry 5.0
# hartnell 1.0
# beatspeare 1.0
# farewells 2.0
# 💓😻👫 1.0
# anti-semitism 39.0
# passion 123.0
# home…have 1.0
# child❣️❣️ 1.0
# under… 2.0
# nose🙂 1.0
# biology 7.0
# 〰 1.0
# manti 1.0
# hiccups 2.0
# https://t.co/lmjtwc5vuk 1.0
# torched 1.0
# you-chan 1.0
# imaginary 8.0
# pat🎉🎈💗 1.0
# mantz 1.0
# plastic 17.0
# iwan 2.0
# https://t.co/tvkjohwcet 1.0
# action... 1.0
# https://t.co/dsksydwso2 1.0
# morning🗻🦌 1.0
# churchgoer 2.0
# https://t.co/x0gqxmdhst 1.0
# https://t.co/m6e3xcd5ey 4.0
# 》 5.0
# blackness 22.0
# 🙌🏽😩 1.0
# 。 1.0
# https://t.co/tjqunflst9 1.0
# anythigng 1.0
# swimming 12.0
# letters 42.0
# kma- 1.0
# *sigh* 10.0
# 🌉🌃⛼ 1.0
# https://t.co/ajrovdyynz 1.0
# 🙏🏾😪 1.0
# https://t.co/uyrhpc5pcu 1.0
# https://t.co/fnccdcrahl 1.0
# https://t.co/wp2emii2lz 1.0
# https://t.co/ntfpxekwxq 1.0
# frl 3.0
# https://t.co/zl77egrr1p 1.0
# ...
# philosophers 2.0
# https://t.co/44hy7ceisy 1.0
# omelet 3.0
# supporter… 1.0
# pitched 5.0
# becasue 1.0
# https://t.co/yf0hslnflu 1.0
# https://t.co/cepjzxfilk 1.0
# illustrator 1.0
# hypoallergenic 1.0
# embedded 1.0
# https://t.co/1zsp3rggiz 1.0
# freddy 2.0
# waltzing 1.0
# https://t.co/j91xph9uqy 1.0
# https://t.co/fujk9onagi 1.0
# critics\ 1.0
# https://t.co/p… 8.0
# https://t.co/xxx4nva8uh 1.0
# skjsksksk 1.0
# ⚽equipment😶 1.0
# 60% 18.0
# https://t.co/l95mgkt4nu 1.0
# alaikum 2.0
# kutha😂😂 1.0
# https://t.co/biy8gqrqeu 1.0
# https://t.co/xeaqvajka9 1.0
# https://t.co/q6anbjmzfm 1.0
# cabinets 2.0
# infact 1.0
# blabbering 1.0
# modding 1.0
# selfies😂😊 1.0
# https://t.co/xnf8ew14lq 1.0
# https://t.co/vuyezyo… 1.0
# fools 31.0
# https://t.co/hamseq8tnr 1.0
# https://t.co/2cqso24wqw 1.0
# poor 3029.0
# poop 13.0
# 60s 3.0
# https://t.co/u7p… 1.0
# industry… 6.0
# endeavors 6.0
# whistling 1.0
# vp 45.0
# pooh 3.0
# https://t.co/j8w28febb0 1.0
# pelosi 144.0
# https://t.co/fdh5zfy7bs 9.0
# pool 37.0
# https://t.co/ieyopaq0v6 1.0
# ??!! 2.0
# corel 1.0
# cnblue 2.0
# shantar 1.0
# pageant 1.0
# man👎🏻 1.0
# prerogative 1.0
# corey 11.0
# overseas 9.0
# triggered\ 1.0
# https://t.co/evu64ghz6b 1.0
# https://t.co/lk5bc3fnhx 1.0
# guelph 1.0
# ceases 6.0
# 😍😍💋 1.0
# https://t.co/yfrth9zdjz 1.0
# https://t.co/n2xnexduad 1.0
# pique 1.0
# thoughtful 21.0
# unblock 1.0
# 😍😍💕 1.0
# form...there 2.0
# religious 38.0
# 😍😍💟 1.0
# disassociate 3.0
# https://t.co/ntkoai2zuh 1.0
# imngonna 1.0
# wms 1.0
# tri-c 1.0
# l00k 1.0
# https://t.co/azkqpsbueq 1.0
# wmu 1.0
# danielle 9.0
# jinri 4.0
# ex-situ 1.0
# *nungguin 1.0
# volunteer 13.0
# stressing😌 1.0
# -needs 1.0
# waverly 1.0
# patently 2.0
# https://t.co/aqjuralohx 1.0
# 😮😮 2.0
# chiron 3.0
# aimeé 1.0
# co/ssl8dyqbto 2.0
# “mother” 2.0
# coloured 1.0
# 😮😲 1.0
# tay💖💖💖 1.0
# decide 287.0
# zemgulis 1.0
# chattahoochee 1.0
# much😂😂😂 1.0
# https://t.co/omdcgiohep 1.0
# co/kgle8jcie7 1.0
# naomba 2.0
# trevante 1.0
# https://t.co/3mpejwcegh 1.0
# arg… 2.0
# kondo 1.0
# https://t.co/l23tvy3aqa 1.0
# hbcu 11.0
# https://t.co/dh6alm8mty 1.0
# 😂😂😂😭😭💕 1.0
# konda 1.0
# https://t.co/8dknbkmygw 1.0
# madness/bullshit 1.0
# dunk 74.0
# https://t.co/feuddebf2v 1.0
# bandits 1.0
# streets 42.0
# sm♥️ 2.0
# https://t.co/clhu6inswz 1.0
# orgasm 8.0
# -jules 1.0
# 82.655 1.0
# anyon… 3.0
# http://t.co/wogwt0rkio 1.0
# https://t.co/ugwesfo1la 1.0
# iÕm 1.0
# https://t.co/ow8rfonvqb 1.0
# 1” 1.0
# https://t.co/uoxb7wp9ti 1.0
# entrepreneurial 2.0
# https://t.co/hnsz55uujv 1.0
# serious😂😂 1.0
# doesn't… 5.0
# 🤞 3.0
# first… 5.0
# 🤙 4.0
# /10 3.0
# 🤗 103.0
# 🤕 30.0
# 🤔 235.0
# 🤓 10.0
# 🤒 23.0
# 🤑 9.0
# 🤐 15.0
# https://t.co/xnfjyzxrac 1.0
# acadia 1.0
# https://t.co/m0vtz1a24d 1.0
# excess 8.0
# grapples 1.0
# belize 2.0
# reality. 2.0
# -@nycnal 1.0
# https://t.co/8spc2wv4nh 1.0
# 🤺 1.0
# asb 2.0
# 🤷 3.0
# cathartic 1.0
# shouldn’t 6.0
# https://t.co/pnmhayzin0 25.0
# cou… 9.0
# https://t.co/44wpy4… 2.0
# kriger 1.0
# advertising 15.0
# cathy 4.0
# nbd) 1.0
# 🤤 21.0
# 🤣 27.0
# 🤢 13.0
# asf 169.0
# https://t.co/pl6crl6ypb 1.0
# jre 2.0
# https://t.co/3anjnk5pfk 1.0
# put 1341.0
# me💖💖 1.0
# https://t.co/mg92oh8i1d 1.0
# https://t.co/ttpuqjiwgb 1.0
# https://t.co/fxxlhbetlf 3.0
# https://t.co/3xqjkm50ks 1.0
# ❤🐱🐰❤ 1.0
# https://t.co/yizwv6opzc 1.0
# almost 378.0
# epicenter 1.0
# sisbonding 1.0
# brunswick 1.0
# https://t.co/ujreqvlhv8 1.0
# 🙌🏾 25.0
# lowering 4.0
# 🙌🏼 19.0
# 🙌🏽 19.0
# 🙌🏻 16.0
# https://t.co/dls4qwpiwf 1.0
# dion 1.0
# https://t.co/mib5ux8j6d 2.0
# dior 4.0
# dios 2.0
# https://t.co/n2cci92ewh 4.0
# loseing 1.0
# pretense 3.0
# https://t.co/f6ewrivfxq 1.0
# https://t.co/ehll6dnxsq 1.0
# https://t.co/mvp8pmlkcm 1.0
# https://t.co/xrauyhb68y 1.0
# https://t.co/fafdtk4kwp 4.0
# https://t.co/mdx4hz5jdr 1.0
# (***3/4 1.0
# budgets 3.0
# equali… 1.0
# https://t.co/aojm5ylorb 1.0
# 😭😏😈 1.0
# https://t.co/mbxi4falrr 1.0
# $juno 1.0
# 🙌🏀 1.0
# la’el 1.0
# disposab… 1.0
# deaddd 1.0
# eazy 2.0
# 4-16% 1.0
# abner 1.0
# ‘care’ 2.0
# eazi 1.0
# https://t.co/lzuvwutqpi 1.0
# https://t.co/3ww6xhjeaa 1.0
# ex-lax 1.0
# goals\ 1.0
# okeeee 1.0
# https://t.co/ljiilcuwn1 2.0
# reject 57.0
# anywaaay 1.0
# https://t.co/bpew94zyc2 1.0
# bussy 1.0
# anyoneeee 1.0
# schultz 3.0
# https://t.co/izxqpviipt 2.0
# communicating 4.0
# https://t.co/very9ah569 1.0
# cook\ 2.0
# purring 3.0
# 🙌🏾💙🔐 1.0
# pendeja 2.0
# ulrike 1.0
# https://t.co/kftzqovg9w 1.0
# criticize 40.0
# https://t.co/l7te8kkttx 2.0
# https://t.co/f6vlvmumhj 1.0
# anytime 45.0
# 😘😍❤ 2.0
# gloomy 4.0
# roommates 8.0
# chopsticks 1.0
# affirmations 5.0
# https://t.co/6svuxqckia 1.0
# ghostbusters 3.0
# protpp 1.0
# missss 1.0
# https://t.co/x1lpxkwfsy 1.0
# https://t.co/of34jxcevd 1.0
# aux🙄 1.0
# me😪but 1.0
# lovebirds 4.0
# theworst 1.0
# https://t.co/st6fkzsnrc 1.0
# 😔🤔🤦‍♂️ 4.0
# clarinet 1.0
# flat-irons 1.0
# does/promises 1.0
# https://t.co/nw1u2bhoff 1.0
# https://t.co/ngrdozpmc4 1.0
# https://t.co/kvd08wnkcz 1.0
# https://t.co/jdt39u8j7m 1.0
# absence 16.0
# https://t.co/cnfrr09qfr 1.0
# https://t.co/iikrgtpkwr 1.0
# ordina… 1.0
# evening 275.0
# https://t.co/g2hj6a5f88 1.0
# https://t.co/pyz3vec9e8 1.0
# https://t.co/xb1b6qxlqu 1.0
# hahahahahaha 4.0
# ninja 6.0
# https://t.co/witp2fdxp0 1.0
# https://t.co/h3v63buxbk 1.0
# fair\ 1.0
# *likes 1.0
# netcode 1.0
# faire 1.0
# 😹👏🏼 2.0
# https://t.co/hlkaevtjmj 1.0
# freebies 3.0
# bless 338.0
# effect… 1.0
# https://t.co/ab7dbxecuo 1.0
# https://t.co/nkj68qffzg 1.0
# ooops 7.0
# https://t.co/hfgjxhcx9l 1.0
# fairy 15.0
# bbbeeeee 1.0
# obligated 7.0
# you´re 1.0
# heavy 34.0
# transcribe 2.0
# https://t.co/5d6xcqyhig 1.0
# https://t.co/kn11u4mmpc 1.0
# https://t.co/uzdvp8oqwh 1.0
# wasn't.. 1.0
# https://t.co/5ntkc8zstv 1.0
# https://t.co/4xtspwoom7 1.0
# ahead/forward 1.0
# babies😊 1.0
# heave 2.0
# anarchy 3.0
# https://t.co/m0r1cjapjz 1.0
# //can 1.0
# hispanics/illegal 1.0
# 😂😍🙏🏽💙 1.0
# https://t.co/dpzn… 1.0
# redamancy 1.0
# chubssssssss 1.0
# https://t.co/gmn7uwhgxf 1.0
# america- 1.0
# cigarettes😷they 1.0
# wwjd 1.0
# alexismonique1 2.0
# 👋🏽 2.0
# 👋🏼 5.0
# doppler 1.0
# 👋🏻 1.0
# https://t.co/8puy3piu8h 47.0
# https://t.co/1qt0yp1ik6 1.0
# happy14thanniversa… 2.0
# https://t.co/tjqvbtcxtb 1.0
# pseudomonas 1.0
# straightened 4.0
# 😡😂 1.0
# dishwasher 2.0
# yowsers 1.0
# https://t.co/mj5ks5xhzs 1.0
# autu- 1.0
# https://t.co/gzfosl2mpz 1.0
# american 585.0
# →… 1.0
# gintoki 1.0
# 😡😡 3.0
# grandstand 2.0
# 😡😤 4.0
# drooling 2.0
# https://t.co/wacbiu8vdb 1.0
# ido3d 1.0
# effortless 3.0
# visions 23.0
# giuliani 1.0
# equating 1.0
# 😭❤️✨🌹 1.0
# cheeseheads 1.0
# \nto 1.0
# lovatic 1.0
# https://t.co/xjqrnihyq8 1.0
# hewit 3.0
# https://t.co/iterlb6rwz 1.0
# vision\ 1.0
# prejudice\n5 1.0
# https://t.co/zpawir5lfb 1.0
# https://t.co/v40k5gi1xx 1.0
# centrali… 2.0
# rawr 3.0
# trapped 13.0
# "ryan" 1.0
# mhmm 1.0
# https://t.co/8cp8truzkh 2.0
# nokris 1.0
# the\n 1.0
# co/1qnfysttvq 1.0
# job🙄 1.0
# basah 1.0
# job🙃 1.0
# job🙌 1.0
# *same 1.0
# koozie 1.0
# assaulted 6.0
# https://t.co/5rgmrnmtib 1.0
# imperiled 1.0
# https://t.co/bla5fcaddl 1.0
# raw\ 1.0
# https://t.co/g6dm6jxtzn 1.0
# touch😉 1.0
# https://t.co/3pken91tph 1.0
# https://t.co/pk99v7udfj 1.0
# toward 54.0
# charlotte 4.0
# 🐇❤️🐰💕🎂 6.0
# phobia 2.0
# https://t.co/xdondfagzu 1.0
# https://t.co/o0dlnxi5ys 1.0
# wasnt 41.0
# 💔💔💔 1.0
# 888 2.0
# overstate 3.0
# jamil 2.0
# https://t.co/dzm6rpt4ff 1.0
# randomly 36.0
# well-written 2.0
# palmrests 1.0
# 88% 5.0
# https://t.co/ofpdtmmdwt 1.0
# https://t.co/s9hslup9ym 1.0
# antonio 7.0
# organs 3.0
# eff… 1.0
# beaners 1.0
# https://t.co/kxm2v3jgou 1.0
# https://t.co/zrzo3jqnfg 1.0
# greatness… 1.0
# flexin 3.0
# https://t.co/gzn2pho8tu 1.0
# matiis 1.0
# offscreen 1.0
# https://t.co/aexwrfp797 1.0
# haechan 1.0
# israel\n#jointaddress 1.0
# 🐶🐶🐶🐶🌸🌼🌺🌷🌹💐💐💐🎈💕 1.0
# beautifully… 1.0
# https://t.co/vlizmyh9ih 1.0
# natalya 1.0
# https://t.co/qmfycsw8fl 1.0
# https://t.co/m5i5fjubqr 1.0
# https://t.co/j1filvirit 1.0
# muscle 22.0
# night❤❤ 1.0
# https://t.co/sebkuqmcyr 4.0
# rockefeller 9.0
# dunkers 1.0
# dab… 1.0
# https://t.co/1ufjbhrqgi 1.0
# velocity 2.0
# t-pain 1.0
# physics 10.0
# ziggler 7.0
# |anonim 1.0
# https://t.co/5adx6ro02v 1.0
# stalked 3.0
# sorry” 1.0
# abdullah 1.0
# https://t.co/eeffetiyyw 1.0
# x100 2.0
# https://t.co/ee5iy8habm 1.0
# https://t.co/aiayzasqlc 1.0
# slum… 3.0
# weho 1.0
# https://t.co/bz4pivk9yq 6.0
# https://t.co/exkfediawq 1.0
# counterstrike 1.0
# heavens 5.0
# https://t.co/wxmf0kfbzv 2.0
# yms 1.0
# https://t.co/qkttsahryt 1.0
# https://t.co/03wxur1zvf 1.0
# 🙏🙏🌹🌹🙏🙏 1.0
# https://t.co/8rsuwu59hb 4.0
# https://t.co/zikbkjdkfw 1.0
# ymg 1.0
# ikon 11.0
# sorry… 1.0
# rotterdam 1.0
# https://t.co/tmmsurpzxk 1.0
# abah 1.0
# https://t.co/tcokd5xxok 1.0
# woodall 1.0
# https://t.co/oytjgpvjsl 2.0
# https://t.co/ujhk6iixxp 1.0
# competing 5.0
# boils 3.0
# https://t.co/bqx6iossda 1.0
# https://t.co/ugfp0i6fzs 1.0
# hatemonger 1.0
# adlib 1.0
# fluff 2.0
# https://t.co/it8csftxo2 1.0
# https://t.co/wps8pe2031 1.0
# tossing 3.0
# https://t.co/qqlhmcdxbl 1.0
# https://t.co/wksxb2axy2 1.0
# hype 62.0
# https://t.co/k4lafv3vh5 1.0
# https://t.co/dgnjqmgp66 1.0
# ..................................................................................................................... 1.0
# 1)i 1.0
# https://t.co/f1bgfbvvk9 1.0
# https://t.co/xlopvcdosd 1.0
# those\ 2.0
# gro… 2.0
# wealthy… 1.0
# boyzzzz 1.0
# mantra 7.0
# emmigrant 1.0
# 🤦🏽‍♂️😪 1.0
# mantri 1.0
# https://t.co/u89lavc44w 1.0
# locals 5.0
# transpare… 1.0
# https://t.co/gfe80ngquu 1.0
# *politely 1.0
# promposals 1.0
# work,it 1.0
# tolls 1.0
# https://t.co/p6yccj0g2f 1.0
# local\ 1.0
# thongs 3.0
# veryyyy 4.0
# forevverrr 1.0
# ralways 3.0
# pancake-like 9.0
# https://t.co/mgqsbswnhy 2.0
# black/brown 9.0
# favvvvvv 1.0
# birthday🎉🎉🎊🎊 1.0
# https://t.co/5ao9uigjwi 21.0
# •teaser 4.0
# vanderbilt 8.0
# https://t.co/jzirskiodb 1.0
# 😍😍😍👏👏 2.0
# snitches 1.0
# https://t.co/arjqn6an8b 3.0
# woode… 1.0
# https://t.co/8od7xsenzi 1.0
# abruptly 1.0
# league 92.0
# \n\nair 1.0
# https://t.co/gpzin2su65 1.0
# memorized 3.0
# wouldn't 392.0
# chastising 1.0
# https://t.co/48fmwhqt19 1.0
# w/power 2.0
# https://t.co/bwz9iznplf 1.0
# canadians 8.0
# ya😂😂💕 1.0
# https://t.co/n7tm7n4ada 1.0
# 🤙🏻🎉 1.0
# https://t.co/lasceuplmp 1.0
# oversleep 1.0
# https://t.co/nuzlpcftb4 1.0
# https://t.co/ttdw6zfsug 1.0
# subsidised 1.0
# cskaueosv 1.0
# proton 3.0
# https://t.co/rqyhz8reqq 1.0
# https://t.co/kzhnc48drl 1.0
# https://t.co/ixe9klp4n4 1.0
# sis❤ 1.0
# kearnysville 1.0
# mathematically 1.0
# https://t.co/jh7p7kwwag 1.0
# xtreme 1.0
# macau 1.0
# https://t.co/0ksipvzajo 1.0
# ―confucius 1.0
# odeeee 1.0
# omooo 1.0
# hig… 1.0
# https://t.co/sjq8iae24x 1.0
# https://t.co/xvvdwtxsak 1.0
# https://t.co/wjcsxzdz9n 1.0
# empty 85.0
# https://t.co/uai6ndsykc 1.0
# kisses\ 1.0
# flogging 1.0
# ada 4.0
# https://t.co/de1vgm3e4q 1.0
# juicy 9.0
# https://t.co/tmburizm3w 1.0
# pranam 1.0
# https://t.co/tczjgbmrbh 3.0
# https://t.co/oofqsgckle 1.0
# https://t.co/yvm6mayvbb 1.0
# enuf* 1.0
# https://t.co/unsformm91 1.0
# https://t.co/nxn6uamjwo.own 1.0
# phora 2.0
# ndoes 1.0
# https://t.co/7xemlgtobu 1.0
# https://t.co/h0vrejc2oo 1.0
# https://t.co/n3ykeani2p 1.0
# tristans 1.0
# 9… 1.0
# accidently 4.0
# https://t.co/gidmmiakvs 1.0
# princess😍❤️ 1.0
# 😩😩😂😂😂 2.0
# sombra 1.0
# higher… 1.0
# ✨🕌🙏🏻😇😇✨ 1.0
# 👀🤔 2.0
# https://t.co/872alphqey 1.0
# kroger 1.0
# https://t.co/krbvujttxr 1.0
# https://t.co/5aoc3tcvyy 2.0
# https://t.co/mp0czqbeii 1.0
# synchronicit 1.0
# brittni 1.0
# https://t.co/xbmninwlcs 1.0
# communal 3.0
# -jg 2.0
# celipia 1.0
# grant 11.0
# accomplished 95.0
# macan 1.0
# https://t.co/4rvkkjbowc 1.0
# karl 2.0
# grand 44.0
# thixo 1.0
# composition 3.0
# crunchy-hime 1.0
# classmates 7.0
# fatty 1.0
# gw 2.0
# https://t.co/yzzcm5zyey 1.0
# https://t.co/pllwosqxkb 1.0
# https://t.co/2fsanimux2 1.0
# https://t.co/j3riav1yrb 57.0
# https://t.co/dfafo0yrzo 1.0
# man😂😂 1.0
# holts 1.0
# me🤥 1.0
# https://t.co/hc2ydqftb4 1.0
# arturo 1.0
# vitriol 3.0
# dicking 2.0
# mobb 1.0
# https://t.co/tpf58kaqew 1.0
# https://t.co/mxaywrgmhd 1.0
# don… 4.0
# synopsis 4.0
# moby 1.0
# influx 1.0
# loveeee 5.0
# https://t.co/883alga5md 1.0
# \ntook 1.0
# sett… 1.0
# https://t.co/p5yuk9gfn5 1.0
# 45,417 1.0
# https://t.co/iaffwjfoof 1.0
# -gotta 1.0
# procrastinating 9.0
# gettin… 2.0
# https://t.co/cxgy5baivw 1.0
# https://t.co/sgi0nxz96g 1.0
# sassier 1.0
# https://t.co/twqxf5l0hs 1.0
# https://t.co/t7dlinvzfj 1.0
# stapp 1.0
# questioned 8.0
# 🙂🐦 1.0
# https://t.co/8d2uzb4wye 1.0
# promposal 1.0
# happy😌 1.0
# happy😍 1.0
# https://t.co/xy6grtsosl 1.0
# https://t.co/rfxdh7tcnz 1.0
# ight 7.0
# shirogane。 1.0
# happy😊 1.0
# 🌷\n 1.0
# showing 672.0
# happy😇 1.0
# dearly 30.0
# thunderstorms😻⛈ 1.0
# https://t.co/m7fzcnoaiz 1.0
# optician 1.0
# auston 8.0
# https://t.co/3rhmvpxlrm 1.0
# https://t.co/qqtlpu738s 1.0
# keke 4.0
# mexi 1.0
# 61 3.0
# softness 2.0
# pippen 1.0
# https://t.co/bdkelnkgaz 1.0
# terminology 3.0
# prescriptionnnnn 1.0
# duuuh 1.0
# sketch 10.0
# hah… 1.0
# ashia 1.0
# yolo 4.0
# yolk 1.0
# doublespeak 1.0
# https://t.co/mxlmkxymmx 1.0
# lips 97.0
# https://t.co/icmsnstolq 1.0
# sayeda 1.0
# taeyong 7.0
# 😂😂😂😩i 1.0
# gracia 6.0
# kourt 1.0
# gracie 8.0
# dilapidated 1.0
# https://t.co/zqtfzpfpxo 1.0
# https://t.co/t7ov9scuwi 1.0
# competitions 2.0
# https://t.co/u3h4fsm7gl 2.0
# simmer 2.0
# https://t.co/aspasqvdga 1.0
# timberview 1.0
# you》 2.0
# lip* 1.0
# co/iyfqk6njcc 1.0
# undergone 1.0
# assists 22.0
# 🙌🏻🙌🏻 2.0
# adrian… 1.0
# https://t.co/ujh0rcdwnn 1.0
# offside 6.0
# girly💗💗 1.0
# roblox 6.0
# https://t.co/s1zwv3aeqr 1.0
# papua 1.0
# https://t.co/l7em0jfv58 1.0
# 😍😋😈😘 1.0
# silence 50.0
# carryn 59.0
# https://t.co/vacilasz8b 1.0
# nlookin 22.0
# 🌘😴🙏🌜❤💤💤💤 1.0
# 6600 1.0
# man🙌🏿🙌🏿🙌🏿 1.0
# along… 12.0
# presupposes 1.0
# https://t.co/l1etxyzrpi 1.0
# alison 3.0
# reworked 1.0
# 💎-lit-jay1738 1.0
# robust 1.0
# infuriating 7.0
# https://t.co/cshxqo66an 1.0
# https://t.co/lnzke8u63s 2.0
# placing 13.0
# ⚡️🔥#goheels 1.0
# visas 5.0
# https://t.co/vni4xtjhti 1.0
# ymthat 1.0
# tobey 1.0
# https://t.co/tmlqidakwe 1.0
# withholding 1.0
# unrealist… 2.0
# hgtv 5.0
# 🤷🏻‍♀️👍🏻 1.0
# arima 2.0
# sex...don't 1.0
# authority 14.0
# tragically 1.0
# toben 1.0
# https://t.co/xlnz81dmia 2.0
# https://t.co/16kutfgyfa 1.0
# spirit… 1.0
# viciously 4.0
# https://t.co/lhjmqb9gi0 1.0
# https://t.co/dkcw6vhggo 1.0
# https://t.co/xjrs8ejtvz 1.0
# https://t.co/ne8zbe36ev 1.0
# https://t.co/eyyerhecw3 1.0
# similar 28.0
# zionists 1.0
# fear\ 1.0
# ordered 22.0
# donghyuck 2.0
# yourself… 1.0
# https://t.co/bm0qismaga 1.0
# gaudreau 1.0
# https://t.co/bjojjyfwkr 1.0
# btw\ 1.0
# yuchun 1.0
# fear@ 1.0
# btwb 1.0
# btwn 8.0
# fears 28.0
# https://t.co/msxmrml7sf 1.0
# 82.759 1.0
# application 5.0
# 😊❤️ 6.0
# https://t.co/ztlxkprpjq 1.0
# department 21.0
# aprons 1.0
# https://t.co/selhtqjbjz 1.0
# hangout#gcpstechtalk 1.0
# day💞 1.0
# smiler 1.0
# smiles 63.0
# https://t.co/hxwugx148s 1.0
# https://t.co/wz02ulzkcl 9.0
# smiley 6.0
# alli 2.0
# https://t.co/bykxoiupfo 1.0
# ☀️ 21.0
# https://t.co/cvjbpjhq7l 1.0
# https://t.co/hwoxvl4mxr 1.0
# smiled 11.0
# docus 1.0
# choreos 1.0
# approving 1.0
# https://t.co/vd6awn1q7f 1.0
# https://t.co/6rcczfabqf 6.0
# https://t.co/6iv5xlfomt 1.0
# correlated 1.0
# btw- 1.0
# https://t.co/plf0tnhu5f 1.0
# wasn… 1.0
# btw) 1.0
# https://t.co/ed7dpwdq2w 2.0
# correlates 1.0
# https://t.co/zwqdrghy8h 1.0
# bribe 1.0
# Ｉ 1.0
# garrett 8.0
# 😘😙😞🙂😗😞😘😞 1.0
# sis… 1.0
# mcilroy 2.0
# https://t.co/nuo9y84d7c 1.0
# girls/guys 2.0
# ldshsahdowlady 1.0
# https://t.co/3v8onxxo2w
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-9b6a71777a9b> in <module>()
#       2 word_to_ccdict = distsim.load_contexts("nytcounts.4k")
#       3 # print word_to_ccdict.values()[:5]
# ----> 4 similarity_dic = distsim.construct_simliarity_dic(word_count_dic)
#       5 # top_50 = similarity_dic.items()
#       6 ###Provide your answer below; perhaps in another cell so you don't have to reload the data each time
#
# /Users/juconghe/Documents/CS585/hw3/distsim.pyc in construct_simliarity_dic(word_dic)
#      69     similarity_dic = defaultdict(float)
#      70     for key1, value1 in word_dic.iteritems():
# ---> 71         print key1,value1
#      72         # for key2, value2 in word_dic.iteritems():
#      73         #     if not key1 == key2:
#
# /Users/juconghe/anaconda/envs/2.7/lib/python2.7/site-packages/ipykernel/iostream.pyc in write(self, string)
#     350             is_child = (not self._is_master_process())
#     351             # only touch the buffer in the IO thread to avoid races
# --> 352             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     353             if is_child:
#     354                 # newlines imply flush in subprocesses
#
# /Users/juconghe/anaconda/envs/2.7/lib/python2.7/site-packages/ipykernel/iostream.pyc in schedule(self, f)
#     183         If the thread is not running, call immediately.
#     184         """
# --> 185         if self.thread.is_alive():
#     186             event_id = os.urandom(16)
#     187             while event_id in self._events:
#
# /Users/juconghe/anaconda/envs/2.7/lib/python2.7/threading.pyc in isAlive(self)
#     993         """
#     994         assert self.__initialized, "Thread.__init__() not called"
# --> 995         return self.__started.is_set() and not self.__stopped
#     996
#     997     is_alive = isAlive
#
# KeyboardInterrupt:

# %% [markdown]
# ## Question 7 (10 points)
#
# In the next several questions, you'll examine similarities in trained word embeddings, instead of raw context counts.
#
# See the file `nyt_word2vec.university_cat_dog`, which contains word embedding vectors pretrained by word2vec [1] for three words: “dog”, “cat”, and “university”, from the same corpus. You can open the file in a text editor since it’s quite small.
#
# Write a function which takes word embedding vectors of two words and calculates cossine similarity between these 2 words. The function should return a number beween -1 and 1. Briefly comment on whether the relative simlarities make sense.
#
# *Implementation note:*
# Notice that the inputs of this function are numpy arrays (v1 and v2). If you are not very familiar with the basic operation in numpy, you can find some examples in the basic operation section here:
# https://docs.scipy.org/doc/numpy-dev/user/quickstart.html
#
# If you know how to use Matlab but haven't tried numpy before, the following link should be helpful:
# https://docs.scipy.org/doc/numpy-dev/user/numpy-for-matlab-users.html
#
# [1] Mikolov, Tomas, et al. "Distributed representations of words and phrases and their compositionality." NIPS 2013.

# %%
import distsim; reload(distsim)

word_to_vec_dict = distsim.load_word2vec("nyt_word2vec.4k")

# write code here to show output (i.e. cosine similarity between these words.)
# We encourage you to write other functions in distsim.py itself.

# %% [markdown]
# **Write your response here:**

# %% [markdown]
# ## Question 8 (20 points)
#
# Repeat the process you did in the question 6, but now use dense vector from word2vec. Comment on whether the outputs makes sense. Compare the outputs of using nearest words on word2vec and the outputs on sparse context vector (so we suggest you to use the same words in question 6). Which method works better on the query words you choose. Please brief explain why one method works better than other in each case.
#
# Not: we used the default parameters of word2vec in [gensim](https://radimrehurek.com/gensim/models/word2vec.html) to get word2vec word embeddings.

# %%
import distsim
word_to_vec_dict = distsim.load_word2vec("nyt_word2vec.4k")
###Provide your answer below

# %% [markdown]
# ## Question 9 (15 points)
# An interesting thing to try with word embeddings is analogical reasoning tasks. In the following example, it's intended to solve the analogy question "king is to man as what is to woman?", or in SAT-style notation,
#
# king : man :: ____ : woman
#
# Some research has proposed to use additive operations on word embeddings to solve the analogy: take the vector $(v_{king}-v_{man}+v_{woman})$ and find the most-similar word to it.  One way to explain this idea: if you take "king", get rid of its attributes/contexts it shares with "man", and add in the attributes/contexts of "woman", hopefully you'll get to a point in the space that has king-like attributes but the "man" ones replaced with "woman" ones.
#
# Show the output for 20 closest words you get by trying to solve that analogy with this method.  Did it work?
#
# Please come up with another analogical reasoning task (another triple of words), and output the answer using the same method. Comment on whether the output makes sense. If the output makes sense, explain why we can capture such relation between words using an unsupervised algorithm. Where does the information come from? On the other hand, if the output does not make sense, propose an explanation why the algorithm fails on this case.
#
#
# Note that the word2vec is trained in an unsupervised manner just with distributional statistics; it is interesting that it can apparently do any reasoning at all.  For a critical view, see [Linzen 2016](http://www.aclweb.org/anthology/W/W16/W16-2503.pdf).

# %%
# Write code to show output here.

# %% [markdown]
# ### Textual answer here.
